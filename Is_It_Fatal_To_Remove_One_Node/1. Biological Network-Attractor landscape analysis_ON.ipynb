# %% [markdown]
# ## Attractor Landscape analysis
#
# This is an example of how Boolean network model was analyzed in our paper.
#
# We provide the codes for 'Attractor landscape analysis', 'Perturbation analysis', and 'Analysis of network dynamics' (Please refer to the Method section).

# %%
import numpy as np
import pandas as pd
import itertools
import networkx as nx
import copy
import os

from pyboolnet.file_exchange import bnet2primes, primes2bnet
from pyboolnet.interaction_graphs import primes2igraph
from pyboolnet.state_transition_graphs import primes2stg
from pyboolnet.attractors import compute_attractors_tarjan

from modules.attractorSim import rand_initial_states, compute_attractor_from_primes, compute_phenotype, Simulation
from modules.printlogic import print_node_logic

# %%
network_dir = './network/'
model_file = network_dir + 'EMT_Network.bnet'
primes = bnet2primes(model_file)
nodeList = list(primes.keys())
graph = primes2igraph(primes)
update_mode = "synchronous"

# nodes_order = sorted(primes.keys())  # 이미 선언된 상태여야 함
nodes_order = sorted(primes.keys())
print("총 노드 수:", len(nodes_order))
print("앞 40개 노드:", nodes_order[:40])

# (붙여넣기용) 자동 마커/phenotype 생성
# --- 위 2) 셀의 코드 전체를 여기에 붙여 넣으면 됨 ---

# --- 시작: phenotype/markers 자동 설정 (복붙해서 기존 phenotype 셀 대신 사용) ---
# nodes_order는 위에서 확인한 primes의 정렬된 노드 리스트

# 1) 마커 자동 찾기: E-cad (E-cadherin 계열)과 ZEB1 계열 노드 이름 검색
def find_node_by_keywords(nodes_order, keywords):
    for n in nodes_order:
        lower = n.lower()
        for kw in keywords:
            if kw.lower() in lower:
                return n
    return None

ecad_candidates = ["ecad", "cdh1", "e-cad", "ecadherin"]
zeb_candidates  = ["zeb1", "zeb"]

Ecad_node = find_node_by_keywords(nodes_order, ecad_candidates)
ZEB_node  = find_node_by_keywords(nodes_order, zeb_candidates)

if not Ecad_node or not ZEB_node:
    raise RuntimeError(f"E-cad 또는 ZEB1 노드를 찾을 수 없음. nodes 예시: {nodes_order[:30]}")

print("Detected markers -> E-cad:", Ecad_node, ", ZEB1:", ZEB_node)

# 2) markers 변수 (노트북의 기존 markers 변수 대체)
markers = [Ecad_node, ZEB_node]

# 3) phenotype 정의: 논문 기준 (Epithelial / Mesenchymal / Hybrid)
# P1..P4은 모든 조합(1/0) 중 논문에서 말한 4개 조합(원하면 이름 바꿔도 됨)
phenotype = {
    'P_epithelial': {Ecad_node:1, ZEB_node:0},   # epithelial (E-cad + / ZEB1 -)
    'P_mesenchymal': {Ecad_node:0, ZEB_node:1},  # mesenchymal (E-cad - / ZEB1 +)
    'P_hybrid_high': {Ecad_node:1, ZEB_node:1},  # hybrid (E-cad + / ZEB1 +)
    'P_hybrid_low' : {Ecad_node:0, ZEB_node:0}   # hybrid (E-cad - / ZEB1 -)
}

# 4) phenotypeAnnot: 숫자 레이블 관례 (논문/분석 용도에 맞게)
# 여기선 epithelial = -1, mesenchymal = +1, hybrid들 = 0 (논문/시각화에서 자주 사용하는 구분)
phenotypeAnnot = {
    'P_epithelial': -1,
    'P_mesenchymal': 1,
    'P_hybrid_high': 0,
    'P_hybrid_low': 0
}

print("phenotype keys:", list(phenotype.keys()))
print("markers:", markers)
# --- 끝 ---


if 2**len(nodeList) >= 100000: num_init = 100000
else:  num_init = 2**len(nodeList)
initState = rand_initial_states(num_init, len(nodeList))
# Out:
# 총 노드 수: 31
# 앞 40개 노드: ['AKT', 'AP1', 'ERK', 'Ecadherin', 'EpCAM', 'GLI', 'GRB2SOS', 'GSK3b', 'IKK', 'MDM2', 'MEK', 'MYC', 'NFKB', 'NOTCH', 'PI3K', 'RAF', 'RAS', 'SMAD23', 'SMAD4', 'Snail', 'TAK1', 'TGFBR', 'TGFb', 'THY1', 'Twist1', 'ZEB1', 'bcatenin', 'miR200', 'miR34', 'p38', 'p53']
# Detected markers -> E-cad: Ecadherin , ZEB1: ZEB1
# phenotype keys: ['P_epithelial', 'P_mesenchymal', 'P_hybrid_high', 'P_hybrid_low']
# markers: ['Ecadherin', 'ZEB1']

# %% [markdown]
# ### Node perturbation analysis

# %%
save_dir = './result/EMT/' 
save_perturbname = save_dir + 'EMT_single_simul_result.csv'

# %%
fix_dict = {'RAS':1}
# allsingles = [{n:1} for n in nodeList] + [{n:0} for n in nodeList]

# %%
perturb_p = pd.DataFrame([]) # average activities of the marker nodes
perturb_s = pd.DataFrame([]) # network stabiltiy 

fix_dict_tmp = copy.deepcopy(fix_dict) # fix_dict는 {'RAS':1} 인 상태

print(fix_dict_tmp) # 현재 적용할 고정 노드 출력

primes_new, pheno_df, att_ave_pd, attrs_dict = Simulation(fix_dict_tmp, primes, update_mode, initState, phenotype, phenotypeAnnot)   

att_ave_pd.to_csv("ras_on_att_ave_pd.csv")
pheno_df.to_csv("ras_on_pheno_df.csv")
# Out:
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.76%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.36%)
#     Cycle Start Str:  1001100100100011100000001000101
#        Step 1 Str:  1001100100100011100000001000101
#        Step 2 Str:  1001000101100001100000000001101
#        Step 3 Str:  0001000101100001100000000001100
#        Step 4 Str:  0001100100100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.87%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 17.76112723350525
#                   Ratio
# phenotype
# P_epithelial   0.013605
# P_hybrid_high  0.498749
# P_mesenchymal  0.487647

# %% [markdown]
# ### Node 하나씩 제거

# %%
# --------------- 로직만 없애는 시뮬레이션 프레임워크 ---------------
# 이 셀은 이전 코드 블록(RAS=1 기본 시뮬레이션) 다음에 실행
import time # time.time() 사용을 위해 필요
import copy # copy.deepcopy() 사용을 위해 필요
import pandas as pd # 결과 저장을 위해 필요
import os # 디렉토리 생성을 위해 필요

# 전역 변수로 이미 정의되어 있어야 할 변수들 확인:
# primes, nodes_order, update_mode, initState, phenotype, phenotypeAnnot, Simulation
fix_dict_for_single_run = {'RAS': 1} # (RAS=1만 고정된 상태에서 로직 제거 시뮬레이션)

print("\n--- 노드별 로직 제거(Logic Disruption) 분석 시작 ---")

# 결과 저장 디렉토리
results_dir_logic_disruption = './logic_disruption_results'
os.makedirs(results_dir_logic_disruption, exist_ok=True)

logic_disruption_results = []

# 원본 primes를 백업 (매 루프마다 초기 상태로 돌려야 하므로)
# primes는 `model_file = network_dir + 'EMT_Network.bnet'` 이후에 로드된 원본
original_primes_backup = copy.deepcopy(primes)

for node_to_disrupt_logic in nodes_order:
    # RAS 노드의 로직은 건드리지 않음 (이미 고정했거나 다른 중요한 기본 노드일 수 있으므로)
    # 필요하다면 다른 특정 노드도 제외 가능
    if node_to_disrupt_logic == 'RAS': # and 'RAS' in fix_dict_for_single_run:
        print(f"\n--- RAS 노드 로직은 건드리지 않음 (기본 고정값 사용) ---")
        continue

    # 1. primes를 현재 루프에 맞게 복사 (항상 원본 primes에서 시작)
    current_primes_for_disruption = copy.deepcopy(original_primes_backup)

    # 2. 해당 노드의 '로직(Boolean function)'을 제거
    #    -> 이 노드는 이제 다른 노드들의 영향을 받지 않고 '항상 1'을 출력한다고 가정
    #    사수님 의도에 따라: '실수로 고려 못했을 경우' = '기능적으로 비활성화'
    #    이를 모델에서는 그 노드가 항상 1 (ON) 값을 내게 함.
    constant_output_value = 1 # 로직 제거된 노드가 '항상 1'을 출력한다고 가정

    # current_primes_for_disruption에서 node_to_disrupt_logic의 Boolean 함수를 변경
    # primes[노드명] = [ [입력_노드_리스트], {(): 출력_값} ] 형태로 변경
    # 입력_노드_리스트를 빈 리스트 `[]`로 만들어 더 이상 입력에 의존하지 않게 하고,
    # {(): 출력_값}으로 항상 `constant_output_value`를 반환하게 함.
    current_primes_for_disruption[node_to_disrupt_logic] = [[], {(): constant_output_value}]
    
    print(f"\n--- 시뮬레이션: '{node_to_disrupt_logic}' 로직 제거 (항상 {constant_output_value} 출력) ---")
    print_node_logic(node_to_disrupt_logic, current_primes_for_disruption)

    # 3. Simulation 호출에 넘길 고정 노드 딕셔너리 생성
    #    RAS 고정 조건에 로직 제거된 노드도 그 고정 값으로 추가
    fix_dict_for_sim_call = copy.deepcopy(fix_dict_for_single_run) # {'RAS':1}
    fix_dict_for_sim_call.update({node_to_disrupt_logic: constant_output_value}) # 예: {'RAS':1, 'AKT':1}

    # Simulation 함수 호출
    try:
        primes_after_disruption, pheno_df_logic, att_ave_pd_logic, attrs_dict_logic = Simulation(
            fix_dict_for_sim_call,       # 이번 시뮬레이션의 고정 노드
            current_primes_for_disruption, # 로직 제거된 노드 정의가 바뀐 primes
            update_mode,
            initState,
            phenotype,
            phenotypeAnnot
        )
        
        # 결과 수집 (KO 시뮬레이션과 동일한 지표 사용)
        logic_disruption_results.append({
            'disrupted_node': node_to_disrupt_logic,
            'fixed_value_after_disruption': constant_output_value,
            'attractor_counts': len(attrs_dict_logic.get('attractors', {})),
            'phenotype_ratios': pheno_df_logic.T.to_dict('records')[0],
            'att_ave_pd_values': att_ave_pd_logic.T.to_dict('records')[0]
        })
    except Exception as e:
        print(f"에러 발생: '{node_to_disrupt_logic}' 로직 제거 시뮬레이션 중 - {e}")
        logic_disruption_results.append({
            'disrupted_node': node_to_disrupt_logic,
            'fixed_value_after_disruption': constant_output_value,
            'error': str(e),
            'attractor_counts': np.nan 
        })

# 결과를 Pandas DataFrame으로 정리
logic_disruption_df = pd.DataFrame(logic_disruption_results)
logic_disruption_df.set_index('disrupted_node', inplace=True)
logic_disruption_df.to_csv(os.path.join(results_dir_logic_disruption, 'node_logic_disruption_analysis_results.csv'))
print(f"\n노드 로직 제거 분석 결과 저장 완료: {os.path.join(results_dir_logic_disruption, 'node_logic_disruption_analysis_results.csv')}")
# Out:
# --- 노드별 로직 제거(Logic Disruption) 분석 시작 ---
#
# --- 시뮬레이션: 'AKT' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'AKT'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.18%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.08%)
#     Cycle Start Str:  1001000101100001100000000001101
#        Step 1 Str:  1001000101100001100000000001101
#        Step 2 Str:  1001000101100001100000000001100
#        Step 3 Str:  1001100100100011100000011000100
#        Step 4 Str:  1001100100100011100000011000101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.74%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  1011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.708368301391602
#                   Ratio
# phenotype
# P_epithelial   0.010772
# P_hybrid_high  0.497399
# P_mesenchymal  0.491829
#
# --- 시뮬레이션: 'AP1' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'AP1'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.36%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.41%)
#     Cycle Start Str:  0101100101100001100000000001100
#        Step 1 Str:  0101100101100001100000000001100
#        Step 2 Str:  0101100100100011100000001000100
#        Step 3 Str:  1101100100100011100000001000101
#        Step 4 Str:  1101100101100001100000000001101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.22%)
#     Cycle Start Str:  1110100001110001100100011111001
#        Step 1 Str:  1110100001110001100100011111001
#        Step 2 Str:  0110100001110000101100011011000
#        Step 3 Str:  1110100001010010101100011010100
#        Step 4 Str:  1100100001010010101000011110100
#        Step 5 Str:  1101100001110011100000011110000
#        Step 6 Str:  1101100000110011100100011110000
#        Step 7 Str:  1100100000110011100100011110001
# --- End of Attractor Listing ---
# Attractor simulation time : 15.970258474349976
#                   Ratio
# phenotype
# P_epithelial   0.014117
# P_mesenchymal  0.985883
#
# --- 시뮬레이션: 'ERK' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'ERK'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 50.11%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Steady State, Basin 40.00%)
#     State Str:  1111000001010010101000011110100
#   > Attractor ID 2 (Steady State, Basin 0.95%)
#     State Str:  1110000001010010101100011110000
#   > Attractor ID 3 (Cyclic, Length 2, Basin 8.93%)
#     Cycle Start Str:  1110000001010010101000011110000
#        Step 1 Str:  1110000001010010101000011110000
#        Step 2 Str:  1111000001010010101100011110100
# --- End of Attractor Listing ---
# Attractor simulation time : 15.197869777679443
#                   Ratio
# phenotype
# P_hybrid_high  0.489327
# P_mesenchymal  0.510673
#
# --- 시뮬레이션: 'Ecadherin' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'Ecadherin'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.01%)
#     State Str:  1111011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.37%)
#     Cycle Start Str:  1001100100100011100000001000101
#        Step 1 Str:  1001100100100011100000001000101
#        Step 2 Str:  1001000101100001100000000001101
#        Step 3 Str:  0001000101100001100000000001100
#        Step 4 Str:  0001100100100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.62%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 16.285550117492676
#                   Ratio
# phenotype
# P_epithelial   0.013667
# P_hybrid_high  0.986333
#
# --- 시뮬레이션: 'EpCAM' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'EpCAM'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.13%)
#     State Str:  1110111011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.37%)
#     Cycle Start Str:  1001100100100011100000001000101
#        Step 1 Str:  1001100100100011100000001000101
#        Step 2 Str:  1001100101100001100000000001101
#        Step 3 Str:  0001100101100001100000000001100
#        Step 4 Str:  0001100100100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.50%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011100001110001100000000111101
#        Step 4 Str:  0011100001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.515569925308228
#                   Ratio
# phenotype
# P_epithelial   0.013674
# P_hybrid_high  0.495000
# P_mesenchymal  0.491326
#
# --- 시뮬레이션: 'GLI' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'GLI'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.83%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.15%)
#     Cycle Start Str:  1001010101100001100000000001101
#        Step 1 Str:  1001010101100001100000000001101
#        Step 2 Str:  0001010101100001100000000001100
#        Step 3 Str:  0001110100100011100000001000100
#        Step 4 Str:  1001110100100011100000001000101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 50.02%)
#     Cycle Start Str:  1100110001010010101000011110100
#        Step 1 Str:  1100110001010010101000011110100
#        Step 2 Str:  1001110001110011100000011110000
#        Step 3 Str:  1001110000110011100100011110000
#        Step 4 Str:  1000110000110011100100011110001
#        Step 5 Str:  1010010001110001100100011111001
#        Step 6 Str:  0110010001110000101100011011000
#        Step 7 Str:  1110110001010010101100011010100
# --- End of Attractor Listing ---
# Attractor simulation time : 17.03915238380432
#                   Ratio
# phenotype
# P_epithelial   0.011455
# P_mesenchymal  0.988545
#
# --- 시뮬레이션: 'GRB2SOS' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'GRB2SOS'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.71%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.36%)
#     Cycle Start Str:  1001001101100011100000000001101
#        Step 1 Str:  1001001101100011100000000001101
#        Step 2 Str:  1001001101100011100000000001100
#        Step 3 Str:  1001101100100011100000011000100
#        Step 4 Str:  1001101100100011100000011000101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.93%)
#     Cycle Start Str:  1101101001010010101000011110100
#        Step 1 Str:  1101101001010010101000011110100
#        Step 2 Str:  1001101001110011100000011110000
#        Step 3 Str:  1001101000110011100000011110000
#        Step 4 Str:  1001101000110011100000011110001
#        Step 5 Str:  1011001001110011100000000111101
#        Step 6 Str:  1011001001100010101000001011100
#        Step 7 Str:  1111101001010010101000011010100
# --- End of Attractor Listing ---
# Attractor simulation time : 17.157727479934692
#                   Ratio
# phenotype
# P_epithelial   0.013584
# P_hybrid_high  0.499332
# P_mesenchymal  0.487083
#
# --- 시뮬레이션: 'GSK3b' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'GSK3b'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.55%)
#     State Str:  1110011111111111111111111100010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 35.31%)
#     Cycle Start Str:  1001100100100011100000001000101
#        Step 1 Str:  1001100100100011100000001000101
#        Step 2 Str:  1001000101100001100000000001101
#        Step 3 Str:  0001000101100001100000000001100
#        Step 4 Str:  0001100100100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 4, Basin 15.13%)
#     Cycle Start Str:  1011100101100011100000011000000
#        Step 1 Str:  1011100101100011100000011000000
#        Step 2 Str:  1101100100110010101000011100100
#        Step 3 Str:  1011100101100011100000011000001
#        Step 4 Str:  1101000101110000101000001101100
# --- End of Attractor Listing ---
# Attractor simulation time : 15.619595527648926
#                   Ratio
# phenotype
# P_epithelial   0.353136
# P_hybrid_high  0.151322
# P_mesenchymal  0.495542
#
# --- 시뮬레이션: 'IKK' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'IKK'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.30%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.37%)
#     Cycle Start Str:  1001100110101011100000001000101
#        Step 1 Str:  1001100110101011100000001000101
#        Step 2 Str:  1001000111101001100000000001101
#        Step 3 Str:  0001000111101001100000000001100
#        Step 4 Str:  0001100110101011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.33%)
#     Cycle Start Str:  1011000011111001100000000111101
#        Step 1 Str:  1011000011111001100000000111101
#        Step 2 Str:  0011000011101000101000001011100
#        Step 3 Str:  1111100011011010101000011010100
#        Step 4 Str:  1101100011011010101000011110100
#        Step 5 Str:  1001100011111011100000011110000
#        Step 6 Str:  1001100010111011100000011110000
#        Step 7 Str:  1001100010111011100000011110001
# --- End of Attractor Listing ---
# Attractor simulation time : 15.898562669754028
#                   Ratio
# phenotype
# P_epithelial   0.013744
# P_hybrid_high  0.493275
# P_mesenchymal  0.492982
#
# --- 시뮬레이션: 'MDM2' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'MDM2'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.99%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Steady State, Basin 29.33%)
#     State Str:  1001100001110011100000011110000
#   > Attractor ID 2 (Steady State, Basin 1.35%)
#     State Str:  1001100101100011100000011000100
#   > Attractor ID 3 (Cyclic, Length 2, Basin 5.06%)
#     Cycle Start Str:  1001100001110011100000011100100
#        Step 1 Str:  1001100001110011100000011100100
#        Step 2 Str:  1001100101100011100000011010000
#   > Attractor ID 4 (Cyclic, Length 2, Basin 5.54%)
#     Cycle Start Str:  1101100001110010101000011100100
#        Step 1 Str:  1101100001110010101000011100100
#        Step 2 Str:  1011100101100011100000011010000
#   > Attractor ID 5 (Cyclic, Length 2, Basin 7.66%)
#     Cycle Start Str:  1101100001110010101000011110100
#        Step 1 Str:  1101100001110010101000011110100
#        Step 2 Str:  1011100001110011100000011110000
#   > Attractor ID 6 (Cyclic, Length 2, Basin 2.07%)
#     Cycle Start Str:  1011100001110011100100011110000
#        Step 1 Str:  1011100001110011100100011110000
#        Step 2 Str:  1100100001110010101000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 19.743249654769897
#                   Ratio
# phenotype
# P_epithelial   0.013496
# P_hybrid_high  0.496590
# P_mesenchymal  0.489914
#
# --- 시뮬레이션: 'MEK' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'MEK'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.20%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Steady State, Basin 39.12%)
#     State Str:  1111000001110010101000011110100
#   > Attractor ID 2 (Steady State, Basin 0.95%)
#     State Str:  1110000001110010101100011110000
#   > Attractor ID 3 (Cyclic, Length 4, Basin 1.00%)
#     Cycle Start Str:  1001100100100011100000001000101
#        Step 1 Str:  1001100100100011100000001000101
#        Step 2 Str:  1001000101100001100000000001101
#        Step 3 Str:  0001000101100001100000000001100
#        Step 4 Str:  0001100100100011100000001000100
#   > Attractor ID 4 (Cyclic, Length 2, Basin 9.72%)
#     Cycle Start Str:  1111000001110010101100011110100
#        Step 1 Str:  1111000001110010101100011110100
#        Step 2 Str:  1110000001110010101000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 16.834838390350342
#                   Ratio
# phenotype
# P_epithelial   0.010047
# P_hybrid_high  0.488431
# P_mesenchymal  0.501522
#
# --- 시뮬레이션: 'MYC' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'MYC'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.98%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.30%)
#     Cycle Start Str:  1001100100110011100000001000101
#        Step 1 Str:  1001100100110011100000001000101
#        Step 2 Str:  1001000101110001100000000001101
#        Step 3 Str:  0001000101110001100000000001100
#        Step 4 Str:  0001100100110011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.72%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001110000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 16.1932635307312
#                   Ratio
# phenotype
# P_epithelial   0.013029
# P_hybrid_high  0.497174
# P_mesenchymal  0.489797
#
# --- 시뮬레이션: 'NFKB' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'NFKB'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.33%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.32%)
#     Cycle Start Str:  0001000101101001100000000001100
#        Step 1 Str:  0001000101101001100000000001100
#        Step 2 Str:  0001100100101011100000001000100
#        Step 3 Str:  1001100100101011100000001000101
#        Step 4 Str:  1001000101101001100000000001101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.35%)
#     Cycle Start Str:  1011000001111001100000000111101
#        Step 1 Str:  1011000001111001100000000111101
#        Step 2 Str:  0011000001101000101000001011100
#        Step 3 Str:  1111100001011010101000011010100
#        Step 4 Str:  1101100001011010101000011110100
#        Step 5 Str:  1001100001111011100000011110000
#        Step 6 Str:  1001100000111011100000011110000
#        Step 7 Str:  1001100000111011100000011110001
# --- End of Attractor Listing ---
# Attractor simulation time : 16.076610565185547
#                   Ratio
# phenotype
# P_epithelial   0.013157
# P_hybrid_high  0.493521
# P_mesenchymal  0.493322
#
# --- 시뮬레이션: 'NOTCH' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'NOTCH'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.90%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 5, Basin 51.10%)
#     Cycle Start Str:  1110000001011110111100011110000
#        Step 1 Str:  1110000001011110111100011110000
#        Step 2 Str:  1100000001011110111100011110000
#        Step 3 Str:  1000100001111111111100011110000
#        Step 4 Str:  1010000001111111111100011110000
#        Step 5 Str:  1110000001111110111100011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 14.75952410697937
#                Ratio
# phenotype
# P_mesenchymal    1.0
#
# --- 시뮬레이션: 'PI3K' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'PI3K'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.97%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.22%)
#     Cycle Start Str:  1001100100100011100000011000101
#        Step 1 Str:  1001100100100011100000011000101
#        Step 2 Str:  1001000101100011100000000001101
#        Step 3 Str:  1001000101100011100000000001100
#        Step 4 Str:  1001100100100011100000011000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.80%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110011100000000111101
#        Step 4 Str:  1011000001100010101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 16.251235008239746
#                   Ratio
# phenotype
# P_epithelial   0.012241
# P_hybrid_high  0.498037
# P_mesenchymal  0.489722
#
# --- 시뮬레이션: 'RAF' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'RAF'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.89%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Steady State, Basin 42.25%)
#     State Str:  1111000001110011101000011110100
#   > Attractor ID 2 (Steady State, Basin 0.75%)
#     State Str:  1110000001110011101100011110000
#   > Attractor ID 3 (Cyclic, Length 4, Basin 1.12%)
#     Cycle Start Str:  1001100100100011100000001000101
#        Step 1 Str:  1001100100100011100000001000101
#        Step 2 Str:  1001000101100001100000000001101
#        Step 3 Str:  0001000101100001100000000001100
#        Step 4 Str:  0001100100100011100000001000100
#   > Attractor ID 4 (Cyclic, Length 2, Basin 7.00%)
#     Cycle Start Str:  1110000001110011101000011110000
#        Step 1 Str:  1110000001110011101000011110000
#        Step 2 Str:  1111000001110011101100011110100
# --- End of Attractor Listing ---
# Attractor simulation time : 17.865395069122314
#                   Ratio
# phenotype
# P_epithelial   0.011163
# P_hybrid_high  0.492478
# P_mesenchymal  0.496359
#
# --- RAS 노드 로직은 건드리지 않음 (기본 고정값 사용) ---
#
# --- 시뮬레이션: 'SMAD23' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'SMAD23'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.26%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 5, Basin 50.74%)
#     Cycle Start Str:  1110000001110010111100011110000
#        Step 1 Str:  1110000001110010111100011110000
#        Step 2 Str:  1110000001010010111100011110000
#        Step 3 Str:  1100000001010010111100011110000
#        Step 4 Str:  1000100001110011111100011110000
#        Step 5 Str:  1010000001110011111100011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 14.785025596618652
#                Ratio
# phenotype
# P_mesenchymal    1.0
#
# --- 시뮬레이션: 'SMAD4' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'SMAD4'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.29%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 5, Basin 50.71%)
#     Cycle Start Str:  1010000001110011101100011110000
#        Step 1 Str:  1010000001110011101100011110000
#        Step 2 Str:  1110000001110010101100011110000
#        Step 3 Str:  1110000001010010101100011110000
#        Step 4 Str:  1100000001010010101100011110000
#        Step 5 Str:  1000100001110011101100011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.155853509902954
#                Ratio
# phenotype
# P_mesenchymal    1.0
#
# --- 시뮬레이션: 'Snail' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'Snail'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.97%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.34%)
#     Cycle Start Str:  1000000101100001100100011101001
#        Step 1 Str:  1000000101100001100100011101001
#        Step 2 Str:  0000000101110001100100011001000
#        Step 3 Str:  0000100100110011100100011000100
#        Step 4 Str:  1000100100100011100100011100101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 48.69%)
#     Cycle Start Str:  1000100000110011100100011110001
#        Step 1 Str:  1000100000110011100100011110001
#        Step 2 Str:  1010000001110001100100011111001
#        Step 3 Str:  0110000001110000101100011011000
#        Step 4 Str:  1110100001010010101100011010100
#        Step 5 Str:  1100100001010010101100011110100
#        Step 6 Str:  1000100001110011100100011110000
#        Step 7 Str:  1000100000110011100100011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.369220495223999
#                Ratio
# phenotype
# P_mesenchymal    1.0
#
# --- 시뮬레이션: 'TAK1' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'TAK1'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.68%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.40%)
#     Cycle Start Str:  1001100100100011100010001000111
#        Step 1 Str:  1001100100100011100010001000111
#        Step 2 Str:  1001000111100001100010000001111
#        Step 3 Str:  0001000111101001100010000001110
#        Step 4 Str:  0001100100101011100010001000110
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.92%)
#     Cycle Start Str:  1101100011010010101010011110110
#        Step 1 Str:  1101100011010010101010011110110
#        Step 2 Str:  1101100011111011100010011110010
#        Step 3 Str:  1001100010111011100110011110010
#        Step 4 Str:  1000100010111011100010011110011
#        Step 5 Str:  1011000011111001100010000111111
#        Step 6 Str:  0011000011101000101010001011110
#        Step 7 Str:  1111100001011010101010011010110
# --- End of Attractor Listing ---
# Attractor simulation time : 17.493695735931396
#                   Ratio
# phenotype
# P_epithelial   0.013992
# P_hybrid_high  0.499241
# P_mesenchymal  0.486767
#
# --- 시뮬레이션: 'TGFBR' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'TGFBR'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 50.11%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Steady State, Basin 49.89%)
#     State Str:  1110011011111011111111011110010
# --- End of Attractor Listing ---
# Attractor simulation time : 14.486129522323608
#                Ratio
# phenotype
# P_mesenchymal    1.0
#
# --- 시뮬레이션: 'TGFb' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'TGFb'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 100.00%)
#     State Str:  1110011011111111111111111110010
# --- End of Attractor Listing ---
# Attractor simulation time : 13.881864309310913
#                Ratio
# phenotype
# P_mesenchymal    1.0
#
# --- 시뮬레이션: 'THY1' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'THY1'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.84%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.34%)
#     Cycle Start Str:  1001100100100011100000011000101
#        Step 1 Str:  1001100100100011100000011000101
#        Step 2 Str:  1001000101100001100000010001101
#        Step 3 Str:  0001000101100001100000010001100
#        Step 4 Str:  0001100100100011100000011000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.82%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000010111101
#        Step 4 Str:  0011000001100000101000011011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 16.437886476516724
#                   Ratio
# phenotype
# P_epithelial   0.013375
# P_hybrid_high  0.498209
# P_mesenchymal  0.488416
#
# --- 시뮬레이션: 'Twist1' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'Twist1'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.76%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.36%)
#     Cycle Start Str:  1001100100100011100000001000101
#        Step 1 Str:  1001100100100011100000001000101
#        Step 2 Str:  1001000101100001100000001001101
#        Step 3 Str:  0001000101100001100000001001100
#        Step 4 Str:  0001100100100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.88%)
#     Cycle Start Str:  1011000001110001100000001111101
#        Step 1 Str:  1011000001110001100000001111101
#        Step 2 Str:  0111000001100000101000001011100
#        Step 3 Str:  1111100001010010101000011010100
#        Step 4 Str:  1101100001010010101000011110100
#        Step 5 Str:  1001100001110011100000011110000
#        Step 6 Str:  1001100000110011100000011110000
#        Step 7 Str:  1001100000110011100000011110001
# --- End of Attractor Listing ---
# Attractor simulation time : 16.746858596801758
#                   Ratio
# phenotype
# P_epithelial   0.013623
# P_hybrid_high  0.498779
# P_mesenchymal  0.487598
#
# --- 시뮬레이션: 'ZEB1' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'ZEB1'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.45%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.38%)
#     Cycle Start Str:  0001000101100001100000000101100
#        Step 1 Str:  0001000101100001100000000101100
#        Step 2 Str:  0001100100100011100000001100000
#        Step 3 Str:  1001100100110011100000001100001
#        Step 4 Str:  1001000101110001100000000101101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.17%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001111100
#        Step 5 Str:  1111000001010010101000011110100
#        Step 6 Str:  1101000001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.468101263046265
#                   Ratio
# phenotype
# P_hybrid_high  0.505522
# P_mesenchymal  0.494478
#
# --- 시뮬레이션: 'bcatenin' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'bcatenin'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.59%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 7, Basin 50.41%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 13.854192733764648
#                   Ratio
# phenotype
# P_hybrid_high  0.504129
# P_mesenchymal  0.495871
#
# --- 시뮬레이션: 'miR200' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'miR200'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.19%)
#     State Str:  1110111011111111111111111011010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.36%)
#     Cycle Start Str:  1001000101100001100000000001101
#        Step 1 Str:  1001000101100001100000000001101
#        Step 2 Str:  0001000101100001100000000001100
#        Step 3 Str:  0001100100100011100000001001100
#        Step 4 Str:  1001100100100011100000001001101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.45%)
#     Cycle Start Str:  1101100001010010101000011011100
#        Step 1 Str:  1101100001010010101000011011100
#        Step 2 Str:  1001100001110011100000011011100
#        Step 3 Str:  1001100000110011100000011011100
#        Step 4 Str:  1001100000110011100000011011101
#        Step 5 Str:  1011000001100001100000000011101
#        Step 6 Str:  0011000001100000101000001011100
#        Step 7 Str:  1111100001010010101000011011100
# --- End of Attractor Listing ---
# Attractor simulation time : 16.18360924720764
#                   Ratio
# phenotype
# P_epithelial   0.508089
# P_hybrid_high  0.491911
#
# --- 시뮬레이션: 'miR34' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'miR34'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 50.17%)
#     State Str:  1110011011111111111111111110110
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.30%)
#     Cycle Start Str:  1001100100100011100000001000101
#        Step 1 Str:  1001100100100011100000001000101
#        Step 2 Str:  1001000101100001100000000001101
#        Step 3 Str:  0001000101100001100000000001100
#        Step 4 Str:  0001100100100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 48.53%)
#     Cycle Start Str:  1001100001110011100000011110100
#        Step 1 Str:  1001100001110011100000011110100
#        Step 2 Str:  1001100000110011100000011110100
#        Step 3 Str:  1001100000110011100000011110101
#        Step 4 Str:  1011000001100001100000000111101
#        Step 5 Str:  0011000001100000101000001011100
#        Step 6 Str:  1111100001010010101000011010100
#        Step 7 Str:  1101100001010010101000011110100
# --- End of Attractor Listing ---
# Attractor simulation time : 15.598845481872559
#                   Ratio
# phenotype
# P_epithelial   0.012952
# P_hybrid_high  0.485299
# P_mesenchymal  0.501748
#
# --- 시뮬레이션: 'p38' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'p38'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.05%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.39%)
#     Cycle Start Str:  0001000101100001100000000001110
#        Step 1 Str:  0001000101100001100000000001110
#        Step 2 Str:  0001100100100011100000001000110
#        Step 3 Str:  1001100100100011100000001000111
#        Step 4 Str:  1001000101100001100000000001111
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.55%)
#     Cycle Start Str:  0011000001100000101000001011110
#        Step 1 Str:  0011000001100000101000001011110
#        Step 2 Str:  1111100001010010101000011010110
#        Step 3 Str:  1101100001010010101000011110110
#        Step 4 Str:  1101100001110011100000011110010
#        Step 5 Str:  1001100000110011100100011110010
#        Step 6 Str:  1000100000110011100000011110011
#        Step 7 Str:  1011000001110001100000000111111
# --- End of Attractor Listing ---
# Attractor simulation time : 16.47344970703125
#                   Ratio
# phenotype
# P_epithelial   0.013914
# P_hybrid_high  0.495539
# P_mesenchymal  0.490547
#
# --- 시뮬레이션: 'p53' 로직 제거 (항상 1 출력) ---
#
# --- 노드 'p53'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 1}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '1'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 6.44%)
#     State Str:  1110011011101111111111111110011
#   > Attractor ID 1 (Steady State, Basin 22.79%)
#     State Str:  1110011011101111111111111011111
#   > Attractor ID 2 (Steady State, Basin 2.13%)
#     State Str:  0001000101100001100000000001101
#   > Attractor ID 3 (Cyclic, Length 2, Basin 1.86%)
#     Cycle Start Str:  0001000101100000101000001001101
#        Step 1 Str:  0001000101100000101000001001101
#        Step 2 Str:  0011000101100001100000000001101
#   > Attractor ID 4 (Cyclic, Length 2, Basin 20.28%)
#     Cycle Start Str:  1110011011101111111111111010011
#        Step 1 Str:  1110011011101111111111111010011
#        Step 2 Str:  1110011011101111111111111111111
#   > Attractor ID 5 (Cyclic, Length 2, Basin 15.33%)
#     Cycle Start Str:  0011000001100001100000000001101
#        Step 1 Str:  0011000001100001100000000001101
#        Step 2 Str:  0001000101100000101000001011101
#   > Attractor ID 6 (Cyclic, Length 5, Basin 31.17%)
#     Cycle Start Str:  0101000001000000101000001011101
#        Step 1 Str:  0101000001000000101000001011101
#        Step 2 Str:  0001100001100001100000000011101
#        Step 3 Str:  0011000001100001100000000011101
#        Step 4 Str:  0011000001100000101000001011101
#        Step 5 Str:  0111000001000000101000001011101
# --- End of Attractor Listing ---
# Attractor simulation time : 19.2340304851532
#                   Ratio
# phenotype
# P_epithelial   0.504914
# P_hybrid_high  0.227904
# P_mesenchymal  0.267182
#
# 노드 로직 제거 분석 결과 저장 완료: ./logic_disruption_results/node_logic_disruption_analysis_results.csv
