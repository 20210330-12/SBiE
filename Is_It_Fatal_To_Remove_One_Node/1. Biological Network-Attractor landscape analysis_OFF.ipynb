# %% [markdown]
# ## Attractor Landscape analysis
#
# This is an example of how Boolean network model was analyzed in our paper.
#
# We provide the codes for 'Attractor landscape analysis', 'Perturbation analysis', and 'Analysis of network dynamics' (Please refer to the Method section).

# %%
import numpy as np
import pandas as pd
import itertools
import networkx as nx
import copy
import os

from pyboolnet.file_exchange import bnet2primes, primes2bnet
from pyboolnet.interaction_graphs import primes2igraph
from pyboolnet.state_transition_graphs import primes2stg
from pyboolnet.attractors import compute_attractors_tarjan

from modules.attractorSim import rand_initial_states, compute_attractor_from_primes, compute_phenotype, Simulation
from modules.printlogic import print_node_logic

# %%
network_dir = './network/'
model_file = network_dir + 'EMT_Network.bnet'
primes = bnet2primes(model_file)
nodeList = list(primes.keys())
graph = primes2igraph(primes)
update_mode = "synchronous"

# nodes_order = sorted(primes.keys())  # 이미 선언된 상태여야 함
nodes_order = sorted(primes.keys())
print("총 노드 수:", len(nodes_order))
print("앞 40개 노드:", nodes_order[:40])

# (붙여넣기용) 자동 마커/phenotype 생성
# --- 위 2) 셀의 코드 전체를 여기에 붙여 넣으면 됨 ---

# --- 시작: phenotype/markers 자동 설정 (복붙해서 기존 phenotype 셀 대신 사용) ---
# nodes_order는 위에서 확인한 primes의 정렬된 노드 리스트

# 1) 마커 자동 찾기: E-cad (E-cadherin 계열)과 ZEB1 계열 노드 이름 검색
def find_node_by_keywords(nodes_order, keywords):
    for n in nodes_order:
        lower = n.lower()
        for kw in keywords:
            if kw.lower() in lower:
                return n
    return None

ecad_candidates = ["ecad", "cdh1", "e-cad", "ecadherin"]
zeb_candidates  = ["zeb1", "zeb"]

Ecad_node = find_node_by_keywords(nodes_order, ecad_candidates)
ZEB_node  = find_node_by_keywords(nodes_order, zeb_candidates)

if not Ecad_node or not ZEB_node:
    raise RuntimeError(f"E-cad 또는 ZEB1 노드를 찾을 수 없음. nodes 예시: {nodes_order[:30]}")

print("Detected markers -> E-cad:", Ecad_node, ", ZEB1:", ZEB_node)

# 2) markers 변수 (노트북의 기존 markers 변수 대체)
markers = [Ecad_node, ZEB_node]

# 3) phenotype 정의: 논문 기준 (Epithelial / Mesenchymal / Hybrid)
# P1..P4은 모든 조합(1/0) 중 논문에서 말한 4개 조합(원하면 이름 바꿔도 됨)
phenotype = {
    'P_epithelial': {Ecad_node:1, ZEB_node:0},   # epithelial (E-cad + / ZEB1 -)
    'P_mesenchymal': {Ecad_node:0, ZEB_node:1},  # mesenchymal (E-cad - / ZEB1 +)
    'P_hybrid_high': {Ecad_node:1, ZEB_node:1},  # hybrid (E-cad + / ZEB1 +)
    'P_hybrid_low' : {Ecad_node:0, ZEB_node:0}   # hybrid (E-cad - / ZEB1 -)
}

# 4) phenotypeAnnot: 숫자 레이블 관례 (논문/분석 용도에 맞게)
# 여기선 epithelial = -1, mesenchymal = +1, hybrid들 = 0 (논문/시각화에서 자주 사용하는 구분)
phenotypeAnnot = {
    'P_epithelial': -1,
    'P_mesenchymal': 1,
    'P_hybrid_high': 0,
    'P_hybrid_low': 0
}

print("phenotype keys:", list(phenotype.keys()))
print("markers:", markers)
# --- 끝 ---


if 2**len(nodeList) >= 100000: num_init = 100000
else:  num_init = 2**len(nodeList)
initState = rand_initial_states(num_init, len(nodeList))
# Out:
# 총 노드 수: 31
# 앞 40개 노드: ['AKT', 'AP1', 'ERK', 'Ecadherin', 'EpCAM', 'GLI', 'GRB2SOS', 'GSK3b', 'IKK', 'MDM2', 'MEK', 'MYC', 'NFKB', 'NOTCH', 'PI3K', 'RAF', 'RAS', 'SMAD23', 'SMAD4', 'Snail', 'TAK1', 'TGFBR', 'TGFb', 'THY1', 'Twist1', 'ZEB1', 'bcatenin', 'miR200', 'miR34', 'p38', 'p53']
# Detected markers -> E-cad: Ecadherin , ZEB1: ZEB1
# phenotype keys: ['P_epithelial', 'P_mesenchymal', 'P_hybrid_high', 'P_hybrid_low']
# markers: ['Ecadherin', 'ZEB1']

# %% [markdown]
# ### Node perturbation analysis

# %%
save_dir = './result/EMT/' 
save_perturbname = save_dir + 'EMT_single_simul_result.csv'

# %%
fix_dict = {'RAS':1}
# allsingles = [{n:1} for n in nodeList] + [{n:0} for n in nodeList]

# %%
perturb_p = pd.DataFrame([]) # average activities of the marker nodes
perturb_s = pd.DataFrame([]) # network stabiltiy 

fix_dict_tmp = copy.deepcopy(fix_dict) # fix_dict는 {'RAS':1} 인 상태

print(fix_dict_tmp) # 현재 적용할 고정 노드 출력

primes_new, pheno_df, att_ave_pd, attrs_dict = Simulation(fix_dict_tmp, primes, update_mode, initState, phenotype, phenotypeAnnot)   

att_ave_pd.to_csv("ras_on_att_ave_pd.csv")
pheno_df.to_csv("ras_on_pheno_df.csv")
# Out:
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.12%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.35%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.53%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 17.719911098480225
#                   Ratio
# phenotype
# P_epithelial   0.013506
# P_hybrid_high  0.495320
# P_mesenchymal  0.491174

# %% [markdown]
# ### Node 하나씩 제거

# %%
# --------------- 로직만 없애는 시뮬레이션 프레임워크 ---------------
# 이 셀은 이전 코드 블록(RAS=1 기본 시뮬레이션) 다음에 실행
import time # time.time() 사용을 위해 필요
import copy # copy.deepcopy() 사용을 위해 필요
import pandas as pd # 결과 저장을 위해 필요
import os # 디렉토리 생성을 위해 필요

# 전역 변수로 이미 정의되어 있어야 할 변수들 확인:
# primes, nodes_order, update_mode, initState, phenotype, phenotypeAnnot, Simulation
fix_dict_for_single_run = {'RAS': 1} # (RAS=1만 고정된 상태에서 로직 제거 시뮬레이션)

print("\n--- 노드별 로직 제거(Logic Disruption) 분석 시작 ---")

# 결과 저장 디렉토리
results_dir_logic_disruption = './logic_disruption_results'
os.makedirs(results_dir_logic_disruption, exist_ok=True)

logic_disruption_results = []

# 원본 primes를 백업 (매 루프마다 초기 상태로 돌려야 하므로)
# primes는 `model_file = network_dir + 'EMT_Network.bnet'` 이후에 로드된 원본
original_primes_backup = copy.deepcopy(primes)

for node_to_disrupt_logic in nodes_order:
    # RAS 노드의 로직은 건드리지 않음 (이미 고정했거나 다른 중요한 기본 노드일 수 있으므로)
    # 필요하다면 다른 특정 노드도 제외 가능
    if node_to_disrupt_logic == 'RAS': # and 'RAS' in fix_dict_for_single_run:
        print(f"\n--- RAS 노드 로직은 건드리지 않음 (기본 고정값 사용) ---")
        continue

    # 1. primes를 현재 루프에 맞게 복사 (항상 원본 primes에서 시작)
    current_primes_for_disruption = copy.deepcopy(original_primes_backup)

    # 2. 해당 노드의 '로직(Boolean function)'을 제거
    #    -> 이 노드는 이제 다른 노드들의 영향을 받지 않고 '항상 0'을 출력한다고 가정
    #    사수님 의도에 따라: '실수로 고려 못했을 경우' = '기능적으로 비활성화'
    #    이를 모델에서는 그 노드가 항상 0 (OFF) 값을 내게 함.
    constant_output_value = 0 # 로직 제거된 노드가 '항상 0'을 출력한다고 가정

    # current_primes_for_disruption에서 node_to_disrupt_logic의 Boolean 함수를 변경
    # primes[노드명] = [ [입력_노드_리스트], {(): 출력_값} ] 형태로 변경
    # 입력_노드_리스트를 빈 리스트 `[]`로 만들어 더 이상 입력에 의존하지 않게 하고,
    # {(): 출력_값}으로 항상 `constant_output_value`를 반환하게 함.
    current_primes_for_disruption[node_to_disrupt_logic] = [[], {(): constant_output_value}]
    
    print(f"\n--- 시뮬레이션: '{node_to_disrupt_logic}' 로직 제거 (항상 {constant_output_value} 출력) ---")
    print_node_logic(node_to_disrupt_logic, current_primes_for_disruption)

    # 3. Simulation 호출에 넘길 고정 노드 딕셔너리 생성
    #    RAS 고정 조건에 로직 제거된 노드도 그 고정 값으로 추가
    fix_dict_for_sim_call = copy.deepcopy(fix_dict_for_single_run) # {'RAS':1}
    fix_dict_for_sim_call.update({node_to_disrupt_logic: constant_output_value}) # 예: {'RAS':1, 'AKT':0}

    # Simulation 함수 호출
    try:
        primes_after_disruption, pheno_df_logic, att_ave_pd_logic, attrs_dict_logic = Simulation(
            fix_dict_for_sim_call,       # 이번 시뮬레이션의 고정 노드
            current_primes_for_disruption, # 로직 제거된 노드 정의가 바뀐 primes
            update_mode,
            initState,
            phenotype,
            phenotypeAnnot
        )
        
        # 결과 수집 (KO 시뮬레이션과 동일한 지표 사용)
        logic_disruption_results.append({
            'disrupted_node': node_to_disrupt_logic,
            'fixed_value_after_disruption': constant_output_value,
            'attractor_counts': len(attrs_dict_logic.get('attractors', {})),
            'phenotype_ratios': pheno_df_logic.T.to_dict('records')[0],
            'att_ave_pd_values': att_ave_pd_logic.T.to_dict('records')[0]
        })
    except Exception as e:
        print(f"에러 발생: '{node_to_disrupt_logic}' 로직 제거 시뮬레이션 중 - {e}")
        logic_disruption_results.append({
            'disrupted_node': node_to_disrupt_logic,
            'fixed_value_after_disruption': constant_output_value,
            'error': str(e),
            'attractor_counts': np.nan 
        })

# 결과를 Pandas DataFrame으로 정리
logic_disruption_df = pd.DataFrame(logic_disruption_results)
logic_disruption_df.set_index('disrupted_node', inplace=True)
logic_disruption_df.to_csv(os.path.join(results_dir_logic_disruption, 'node_logic_disruption_analysis_results.csv'))
print(f"\n노드 로직 제거 분석 결과 저장 완료: {os.path.join(results_dir_logic_disruption, 'node_logic_disruption_analysis_results.csv')}")
# Out:
# --- 노드별 로직 제거(Logic Disruption) 분석 시작 ---
#
# --- 시뮬레이션: 'AKT' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'AKT'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.33%)
#     State Str:  0110011001111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 2.76%)
#     Cycle Start Str:  0011100101100011100000001000000
#        Step 1 Str:  0011100101100011100000001000000
#        Step 2 Str:  0101100100110010101000001100100
#        Step 3 Str:  0011100101100011100000001000001
#        Step 4 Str:  0101000101110000101000001101100
#   > Attractor ID 2 (Cyclic, Length 4, Basin 22.47%)
#     Cycle Start Str:  0101100100110010101000001110100
#        Step 1 Str:  0101100100110010101000001110100
#        Step 2 Str:  0011100001110011100000011100001
#        Step 3 Str:  0101000101110000101000001111100
#        Step 4 Str:  0011100001110011100000011000000
#   > Attractor ID 3 (Cyclic, Length 4, Basin 6.92%)
#     Cycle Start Str:  0001000101100001100000000001101
#        Step 1 Str:  0001000101100001100000000001101
#        Step 2 Str:  0001000101100001100000000001100
#        Step 3 Str:  0001100100100011100000001000100
#        Step 4 Str:  0001100100100011100000001000101
#   > Attractor ID 4 (Cyclic, Length 7, Basin 18.51%)
#     Cycle Start Str:  0011000001110001100000000111101
#        Step 1 Str:  0011000001110001100000000111101
#        Step 2 Str:  0011000001100000101000001011100
#        Step 3 Str:  0111100001010010101000011010100
#        Step 4 Str:  0101100001010010101000011110100
#        Step 5 Str:  0001100001110011100000011110000
#        Step 6 Str:  0001100000110011100000011110000
#        Step 7 Str:  0001100000110011100000011110001
# --- End of Attractor Listing ---
# Attractor simulation time : 18.659948587417603
#                  Ratio
# phenotype
# P_epithelial   0.06924
# P_hybrid_high  0.43746
# P_mesenchymal  0.49330
#
# --- 시뮬레이션: 'AP1' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'AP1'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.74%)
#     State Str:  1010011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.38%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 48.88%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1011100001010010101000011010100
#        Step 6 Str:  1001100001010010101000011110100
#        Step 7 Str:  1001000001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.770225763320923
#                   Ratio
# phenotype
# P_epithelial   0.013784
# P_hybrid_high  0.488785
# P_mesenchymal  0.497431
#
# --- 시뮬레이션: 'ERK' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'ERK'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 14.19%)
#     State Str:  1100111011111111111111111110010
#   > Attractor ID 1 (Steady State, Basin 10.50%)
#     State Str:  1100111111101111111111111100010
#   > Attractor ID 2 (Cyclic, Length 4, Basin 8.52%)
#     Cycle Start Str:  1001100100100011100000001010101
#        Step 1 Str:  1001100100100011100000001010101
#        Step 2 Str:  1001000001100001100000000101101
#        Step 3 Str:  0001000101100001100000000011100
#        Step 4 Str:  0001100000110011100000011000100
#   > Attractor ID 3 (Cyclic, Length 4, Basin 16.50%)
#     Cycle Start Str:  0001000001100001100000000001100
#        Step 1 Str:  0001000001100001100000000001100
#        Step 2 Str:  0001100100100011100000001010100
#        Step 3 Str:  1001100000110011100000011100101
#        Step 4 Str:  1001000101100001100000000011101
#   > Attractor ID 4 (Cyclic, Length 4, Basin 11.00%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 5 (Cyclic, Length 2, Basin 24.80%)
#     Cycle Start Str:  1100111111101111111111111110010
#        Step 1 Str:  1100111111101111111111111110010
#        Step 2 Str:  1100111011111111111111111100010
#   > Attractor ID 6 (Cyclic, Length 4, Basin 14.48%)
#     Cycle Start Str:  1001000001100001100000000111101
#        Step 1 Str:  1001000001100001100000000111101
#        Step 2 Str:  0001000001100001100000000011100
#        Step 3 Str:  0001100000110011100000011010100
#        Step 4 Str:  1001100000110011100000011110101
# --- End of Attractor Listing ---
# Attractor simulation time : 19.662227392196655
#                   Ratio
# phenotype
# P_epithelial   0.360293
# P_hybrid_high  0.144827
# P_mesenchymal  0.494880
#
# --- 시뮬레이션: 'Ecadherin' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'Ecadherin'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.33%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.36%)
#     Cycle Start Str:  0000000101100001100000000001100
#        Step 1 Str:  0000000101100001100000000001100
#        Step 2 Str:  0000100100100011100000001000100
#        Step 3 Str:  1000100100100011100000001000101
#        Step 4 Str:  1000000101100001100000000001101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.31%)
#     Cycle Start Str:  1000100001110011100000011110000
#        Step 1 Str:  1000100001110011100000011110000
#        Step 2 Str:  1000100000110011100000011110000
#        Step 3 Str:  1000100000110011100000011110001
#        Step 4 Str:  1010000001110001100000000111101
#        Step 5 Str:  0010000001100000101000001011100
#        Step 6 Str:  1110100001010010101000011010100
#        Step 7 Str:  1100100001010010101000011110100
# --- End of Attractor Listing ---
# Attractor simulation time : 16.559417724609375
#                   Ratio
# phenotype
# P_hybrid_high  0.013615
# P_mesenchymal  0.986385
#
# --- 시뮬레이션: 'EpCAM' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'EpCAM'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.45%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.36%)
#     Cycle Start Str:  1001000100100011100000001000101
#        Step 1 Str:  1001000100100011100000001000101
#        Step 2 Str:  1001000101100001100000000001101
#        Step 3 Str:  0001000101100001100000000001100
#        Step 4 Str:  0001000100100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.19%)
#     Cycle Start Str:  1111000001010010101000011010100
#        Step 1 Str:  1111000001010010101000011010100
#        Step 2 Str:  1101000001010010101000011110100
#        Step 3 Str:  1001000001110011100000011110000
#        Step 4 Str:  1001000000110011100000011110000
#        Step 5 Str:  1001000000110011100000011110001
#        Step 6 Str:  1011000001110001100000000111101
#        Step 7 Str:  0011000001100000101000001011100
# --- End of Attractor Listing ---
# Attractor simulation time : 15.466837644577026
#                   Ratio
# phenotype
# P_epithelial   0.013604
# P_hybrid_high  0.491929
# P_mesenchymal  0.494467
#
# --- 시뮬레이션: 'GLI' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'GLI'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.14%)
#     State Str:  1110001011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.40%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.46%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 17.0804545879364
#                   Ratio
# phenotype
# P_epithelial   0.014035
# P_hybrid_high  0.494552
# P_mesenchymal  0.491413
#
# --- 시뮬레이션: 'GRB2SOS' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'GRB2SOS'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.15%)
#     State Str:  1110010011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.35%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.50%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 17.178847789764404
#                   Ratio
# phenotype
# P_epithelial   0.013501
# P_hybrid_high  0.494956
# P_mesenchymal  0.491543
#
# --- 시뮬레이션: 'GSK3b' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'GSK3b'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.84%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 7, Basin 50.16%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 14.873838663101196
#                   Ratio
# phenotype
# P_hybrid_high  0.501556
# P_mesenchymal  0.498444
#
# --- 시뮬레이션: 'IKK' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'IKK'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.80%)
#     State Str:  1110011001111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.36%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 48.84%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.803075551986694
#                   Ratio
# phenotype
# P_epithelial   0.013645
# P_hybrid_high  0.488377
# P_mesenchymal  0.497978
#
# --- 시뮬레이션: 'MDM2' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'MDM2'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 13.87%)
#     State Str:  1110011010101111111111111110011
#   > Attractor ID 1 (Steady State, Basin 11.56%)
#     State Str:  1110011010101111111111111011111
#   > Attractor ID 2 (Steady State, Basin 1.68%)
#     State Str:  0001000100100001100000000001101
#   > Attractor ID 3 (Cyclic, Length 2, Basin 0.97%)
#     Cycle Start Str:  0011000100100001100000000001101
#        Step 1 Str:  0011000100100001100000000001101
#        Step 2 Str:  0001000100100000101000001001101
#   > Attractor ID 4 (Cyclic, Length 2, Basin 10.72%)
#     Cycle Start Str:  0011000000100001100000000001101
#        Step 1 Str:  0011000000100001100000000001101
#        Step 2 Str:  0001000100100000101000001011101
#   > Attractor ID 5 (Cyclic, Length 2, Basin 23.89%)
#     Cycle Start Str:  1110011010101111111111111010011
#        Step 1 Str:  1110011010101111111111111010011
#        Step 2 Str:  1110011010101111111111111111111
#   > Attractor ID 6 (Cyclic, Length 5, Basin 37.31%)
#     Cycle Start Str:  0111000000000000101000001011101
#        Step 1 Str:  0111000000000000101000001011101
#        Step 2 Str:  0101000000000000101000001011101
#        Step 3 Str:  0001100000100001100000000011101
#        Step 4 Str:  0011000000100001100000000011101
#        Step 5 Str:  0011000000100000101000001011101
# --- End of Attractor Listing ---
# Attractor simulation time : 21.202766180038452
#                   Ratio
# phenotype
# P_epithelial   0.506816
# P_hybrid_high  0.115591
# P_mesenchymal  0.377592
#
# --- 시뮬레이션: 'MEK' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'MEK'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 21.41%)
#     State Str:  1100111011011111111111111110010
#   > Attractor ID 1 (Steady State, Basin 7.41%)
#     State Str:  1100111111001111111111111100010
#   > Attractor ID 2 (Cyclic, Length 4, Basin 10.23%)
#     Cycle Start Str:  1001000001000001100000000101101
#        Step 1 Str:  1001000001000001100000000101101
#        Step 2 Str:  0001000101000001100000000011100
#        Step 3 Str:  0001100000010011100000011000100
#        Step 4 Str:  1001100100000011100000001010101
#   > Attractor ID 3 (Cyclic, Length 4, Basin 10.93%)
#     Cycle Start Str:  1001100000010011100000011100101
#        Step 1 Str:  1001100000010011100000011100101
#        Step 2 Str:  1001000101000001100000000011101
#        Step 3 Str:  0001000001000001100000000001100
#        Step 4 Str:  0001100100000011100000001010100
#   > Attractor ID 4 (Cyclic, Length 4, Basin 7.81%)
#     Cycle Start Str:  0001000101000001100000000001100
#        Step 1 Str:  0001000101000001100000000001100
#        Step 2 Str:  0001100100000011100000001000100
#        Step 3 Str:  1001100100000011100000001000101
#        Step 4 Str:  1001000101000001100000000001101
#   > Attractor ID 5 (Cyclic, Length 2, Basin 20.78%)
#     Cycle Start Str:  1100111111001111111111111110010
#        Step 1 Str:  1100111111001111111111111110010
#        Step 2 Str:  1100111011011111111111111100010
#   > Attractor ID 6 (Cyclic, Length 4, Basin 21.45%)
#     Cycle Start Str:  1001000001000001100000000111101
#        Step 1 Str:  1001000001000001100000000111101
#        Step 2 Str:  0001000001000001100000000011100
#        Step 3 Str:  0001100000010011100000011010100
#        Step 4 Str:  1001100000010011100000011110101
# --- End of Attractor Listing ---
# Attractor simulation time : 20.238658905029297
#                   Ratio
# phenotype
# P_epithelial   0.289595
# P_hybrid_high  0.214470
# P_mesenchymal  0.495935
#
# --- 시뮬레이션: 'MYC' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'MYC'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.32%)
#     State Str:  1110011011101111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.29%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.39%)
#     Cycle Start Str:  0011000001100000101000001011100
#        Step 1 Str:  0011000001100000101000001011100
#        Step 2 Str:  1111100001000010101000011010100
#        Step 3 Str:  1101100001000010101000011110100
#        Step 4 Str:  1001100001100011100000011110000
#        Step 5 Str:  1001100000100011100000011110000
#        Step 6 Str:  1001100000100011100000011110001
#        Step 7 Str:  1011000001100001100000000111101
# --- End of Attractor Listing ---
# Attractor simulation time : 16.720853090286255
#                   Ratio
# phenotype
# P_epithelial   0.012895
# P_hybrid_high  0.493918
# P_mesenchymal  0.493187
#
# --- 시뮬레이션: 'NFKB' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'NFKB'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.66%)
#     State Str:  1110011011110111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.31%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.04%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.908192157745361
#                   Ratio
# phenotype
# P_epithelial   0.013090
# P_hybrid_high  0.490353
# P_mesenchymal  0.496557
#
# --- 시뮬레이션: 'NOTCH' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'NOTCH'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.68%)
#     State Str:  1110011011111011111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.36%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.96%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 17.08782196044922
#                   Ratio
# phenotype
# P_epithelial   0.013622
# P_hybrid_high  0.499585
# P_mesenchymal  0.486792
#
# --- 시뮬레이션: 'PI3K' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'PI3K'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.38%)
#     State Str:  1110011011111101111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.38%)
#     Cycle Start Str:  0001000101100001100000000001101
#        Step 1 Str:  0001000101100001100000000001101
#        Step 2 Str:  0001000101100001100000000001100
#        Step 3 Str:  0001100100100001100000001000100
#        Step 4 Str:  0001100100100001100000001000101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.24%)
#     Cycle Start Str:  0011000001110001100000000111101
#        Step 1 Str:  0011000001110001100000000111101
#        Step 2 Str:  0011000001100000101000001011100
#        Step 3 Str:  1111100001010000101000011010100
#        Step 4 Str:  1101100001010000101000011110100
#        Step 5 Str:  1001100001110001100000011110000
#        Step 6 Str:  0001100000110001100000011110000
#        Step 7 Str:  0001100000110001100000011110001
# --- End of Attractor Listing ---
# Attractor simulation time : 16.688918352127075
#                   Ratio
# phenotype
# P_epithelial   0.013759
# P_hybrid_high  0.492423
# P_mesenchymal  0.493818
#
# --- 시뮬레이션: 'RAF' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'RAF'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Cyclic, Length 4, Basin 2.10%)
#     Cycle Start Str:  0001000101100000100000000001100
#        Step 1 Str:  0001000101100000100000000001100
#        Step 2 Str:  0001100100100010100000001000100
#        Step 3 Str:  1001100100100010100000001000101
#        Step 4 Str:  1001000101100000100000000001101
#   > Attractor ID 1 (Cyclic, Length 3, Basin 10.58%)
#     Cycle Start Str:  1001100001110010100000011110101
#        Step 1 Str:  1001100001110010100000011110101
#        Step 2 Str:  1011000001100000100000000111100
#        Step 3 Str:  0001100000010010101000011010100
#   > Attractor ID 2 (Cyclic, Length 6, Basin 38.17%)
#     Cycle Start Str:  1001100001110010100000011110100
#        Step 1 Str:  1001100001110010100000011110100
#        Step 2 Str:  1001100000110010100000011110000
#        Step 3 Str:  1001100000110010100000011110001
#        Step 4 Str:  1011000001110000100000000111101
#        Step 5 Str:  0011000001000000101000001011100
#        Step 6 Str:  1101100001010010101000011010100
#   > Attractor ID 3 (Cyclic, Length 4, Basin 49.15%)
#     Cycle Start Str:  1100111011111110111111111110010
#        Step 1 Str:  1100111011111110111111111110010
#        Step 2 Str:  1110111011111110111111111110010
#        Step 3 Str:  1110011011011110111111111110010
#        Step 4 Str:  1100011011011110111111111110010
# --- End of Attractor Listing ---
# Attractor simulation time : 18.330064296722412
#                   Ratio
# phenotype
# P_epithelial   0.021011
# P_hybrid_high  0.487502
# P_mesenchymal  0.491487
#
# --- RAS 노드 로직은 건드리지 않음 (기본 고정값 사용) ---
#
# --- 시뮬레이션: 'SMAD23' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'SMAD23'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.61%)
#     State Str:  1110011011111111101111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 2.62%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 47.77%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 16.652077436447144
#                   Ratio
# phenotype
# P_epithelial   0.026226
# P_hybrid_high  0.477692
# P_mesenchymal  0.496082
#
# --- 시뮬레이션: 'SMAD4' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'SMAD4'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Cyclic, Length 4, Basin 7.65%)
#     Cycle Start Str:  1110111011111111110111111110010
#        Step 1 Str:  1110111011111111110111111110010
#        Step 2 Str:  1110111010111111110111111110010
#        Step 3 Str:  1110111010111111110111111110011
#        Step 4 Str:  1110111011111111110111111110011
#   > Attractor ID 1 (Cyclic, Length 4, Basin 8.55%)
#     Cycle Start Str:  1110111010111111110011111010010
#        Step 1 Str:  1110111010111111110011111010010
#        Step 2 Str:  1111111010111111110111111110111
#        Step 3 Str:  1110111011101111110011111110011
#        Step 4 Str:  1111111011111111110111101111110
#   > Attractor ID 2 (Cyclic, Length 4, Basin 8.65%)
#     Cycle Start Str:  1001000101100001100000000011101
#        Step 1 Str:  1001000101100001100000000011101
#        Step 2 Str:  0011000001100001100000000001100
#        Step 3 Str:  0001100100110010100000001010100
#        Step 4 Str:  1001100000110011100000011100101
#   > Attractor ID 3 (Cyclic, Length 4, Basin 7.07%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 4 (Cyclic, Length 4, Basin 33.92%)
#     Cycle Start Str:  1011000001100001100000000111101
#        Step 1 Str:  1011000001100001100000000111101
#        Step 2 Str:  0011000001100000100000001011100
#        Step 3 Str:  0101100000010010100000011010100
#        Step 4 Str:  1001100000110011100000011110101
#   > Attractor ID 5 (Cyclic, Length 4, Basin 26.05%)
#     Cycle Start Str:  1111111011101111110011101111111
#        Step 1 Str:  1111111011101111110011101111111
#        Step 2 Str:  1111111011101111110011101011110
#        Step 3 Str:  1111111010111111110011111010110
#        Step 4 Str:  1111111010111111110011111110111
#   > Attractor ID 6 (Cyclic, Length 4, Basin 8.10%)
#     Cycle Start Str:  1110111010111111110011111110011
#        Step 1 Str:  1110111010111111110011111110011
#        Step 2 Str:  1111111011111111110111101111111
#        Step 3 Str:  1110111011101111110011111010010
#        Step 4 Str:  1111111010111111110111111110110
# --- End of Attractor Listing ---
# Attractor simulation time : 21.308334589004517
#                   Ratio
# phenotype
# P_epithelial   0.157224
# P_hybrid_high  0.766229
# P_mesenchymal  0.076547
#
# --- 시뮬레이션: 'Snail' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'Snail'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 50.57%)
#     State Str:  1111011011111111111011111110110
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.32%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 48.12%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.576596975326538
#                   Ratio
# phenotype
# P_epithelial   0.013153
# P_hybrid_high  0.986847
#
# --- 시뮬레이션: 'TAK1' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'TAK1'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.35%)
#     State Str:  1110011001111111111101111110000
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.37%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.28%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 16.81358003616333
#                   Ratio
# phenotype
# P_epithelial   0.013702
# P_hybrid_high  0.492781
# P_mesenchymal  0.493516
#
# --- 시뮬레이션: 'TGFBR' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'TGFBR'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Cyclic, Length 4, Basin 1.33%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 1 (Cyclic, Length 4, Basin 0.33%)
#     Cycle Start Str:  0001000101100001100000100001100
#        Step 1 Str:  0001000101100001100000100001100
#        Step 2 Str:  0001100100100011100000101000100
#        Step 3 Str:  1001100100100011100000101000101
#        Step 4 Str:  1001000101100001100000100001101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 48.66%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
#   > Attractor ID 3 (Cyclic, Length 5, Basin 49.68%)
#     Cycle Start Str:  1110000001011110111100111110000
#        Step 1 Str:  1110000001011110111100111110000
#        Step 2 Str:  1100000001011110111100111110000
#        Step 3 Str:  1000100001111111111100111110000
#        Step 4 Str:  1010000001111111111100111110000
#        Step 5 Str:  1110000001111110111100111110000
# --- End of Attractor Listing ---
# Attractor simulation time : 20.542948722839355
#                   Ratio
# phenotype
# P_epithelial   0.016576
# P_hybrid_high  0.486613
# P_mesenchymal  0.496811
#
# --- 시뮬레이션: 'TGFb' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'TGFb'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Cyclic, Length 4, Basin 1.36%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 1 (Cyclic, Length 7, Basin 98.64%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 16.206394910812378
#                   Ratio
# phenotype
# P_epithelial   0.013562
# P_hybrid_high  0.986438
#
# --- 시뮬레이션: 'THY1' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'THY1'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.19%)
#     State Str:  1110011011111111111111101110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.33%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.48%)
#     Cycle Start Str:  1001100000110011100000001110001
#        Step 1 Str:  1001100000110011100000001110001
#        Step 2 Str:  1011000001110001100000000111101
#        Step 3 Str:  0011000001100000101000001011100
#        Step 4 Str:  1111100001010010101000001010100
#        Step 5 Str:  1101100001010010101000001110100
#        Step 6 Str:  1001100001110011100000001110000
#        Step 7 Str:  1001100000110011100000001110000
# --- End of Attractor Listing ---
# Attractor simulation time : 16.75649380683899
#                   Ratio
# phenotype
# P_epithelial   0.013316
# P_hybrid_high  0.494795
# P_mesenchymal  0.491888
#
# --- 시뮬레이션: 'Twist1' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'Twist1'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.32%)
#     State Str:  1110011011111111111111110110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.35%)
#     Cycle Start Str:  0001100100100011100000000000100
#        Step 1 Str:  0001100100100011100000000000100
#        Step 2 Str:  1001100100100011100000000000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.33%)
#     Cycle Start Str:  1001000001110011100000010110000
#        Step 1 Str:  1001000001110011100000010110000
#        Step 2 Str:  1001100000110011100000010110000
#        Step 3 Str:  1001100000110011100000010110001
#        Step 4 Str:  1011000001110001100000000111101
#        Step 5 Str:  0011000001100000101000000011100
#        Step 6 Str:  1011100001010010101000010010100
#        Step 7 Str:  1001100001010010101000010110100
# --- End of Attractor Listing ---
# Attractor simulation time : 16.81647801399231
#                   Ratio
# phenotype
# P_epithelial   0.013504
# P_hybrid_high  0.493303
# P_mesenchymal  0.493193
#
# --- 시뮬레이션: 'ZEB1' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'ZEB1'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.84%)
#     State Str:  1110111011111111111111111010010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.38%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 48.77%)
#     Cycle Start Str:  0011000001100000101000001011100
#        Step 1 Str:  0011000001100000101000001011100
#        Step 2 Str:  1111100001010010101000011010100
#        Step 3 Str:  1101100001010010101000011010100
#        Step 4 Str:  1001100001110011100000011010100
#        Step 5 Str:  1001100000110011100000011010100
#        Step 6 Str:  1001100000110011100000011010101
#        Step 7 Str:  1011000001100001100000000011101
# --- End of Attractor Listing ---
# Attractor simulation time : 15.549474954605103
#                   Ratio
# phenotype
# P_epithelial   0.501551
# P_hybrid_high  0.498449
#
# --- 시뮬레이션: 'bcatenin' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'bcatenin'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.90%)
#     State Str:  1110011011111111111111111100010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 35.07%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 4, Basin 15.03%)
#     Cycle Start Str:  1101100000110010101000011100100
#        Step 1 Str:  1101100000110010101000011100100
#        Step 2 Str:  1011100101100011100000011000001
#        Step 3 Str:  1101000001110000101000001101100
#        Step 4 Str:  1011100101100011100000011000000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.101758241653442
#                   Ratio
# phenotype
# P_epithelial   0.350709
# P_hybrid_high  0.150320
# P_mesenchymal  0.498971
#
# --- 시뮬레이션: 'miR200' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'miR200'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.51%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.36%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000000101
#        Step 4 Str:  0001000101100001100000000000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.13%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000110101
#        Step 4 Str:  0011000001100000101000001110100
#        Step 5 Str:  1111000001010010101000011110100
#        Step 6 Str:  1101000001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 16.58697748184204
#                   Ratio
# phenotype
# P_epithelial   0.013607
# P_hybrid_high  0.491312
# P_mesenchymal  0.495081
#
# --- 시뮬레이션: 'miR34' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'miR34'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 50.30%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.32%)
#     Cycle Start Str:  1001100100110011100000001000001
#        Step 1 Str:  1001100100110011100000001000001
#        Step 2 Str:  1001000101110001100000000001001
#        Step 3 Str:  0001000101110001100000000001000
#        Step 4 Str:  0001100100110011100000001000000
#   > Attractor ID 2 (Cyclic, Length 7, Basin 48.38%)
#     Cycle Start Str:  1000100001110011100100011110000
#        Step 1 Str:  1000100001110011100100011110000
#        Step 2 Str:  1000100000110011100000011110000
#        Step 3 Str:  1001100000110011100000011110001
#        Step 4 Str:  1011000001110001100000000111001
#        Step 5 Str:  0011000001110000101000001011000
#        Step 6 Str:  1111100001010010101100011010000
#        Step 7 Str:  1100100001010010101100011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 16.096514225006104
#                   Ratio
# phenotype
# P_epithelial   0.013208
# P_hybrid_high  0.483828
# P_mesenchymal  0.502965
#
# --- 시뮬레이션: 'p38' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'p38'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.50%)
#     State Str:  1110011011111111111111111110000
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.37%)
#     Cycle Start Str:  0001100100100011100000001000100
#        Step 1 Str:  0001100100100011100000001000100
#        Step 2 Str:  1001100100100011100000001000101
#        Step 3 Str:  1001000101100001100000000001101
#        Step 4 Str:  0001000101100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.14%)
#     Cycle Start Str:  1001100000110011100000011110000
#        Step 1 Str:  1001100000110011100000011110000
#        Step 2 Str:  1001100000110011100000011110001
#        Step 3 Str:  1011000001110001100000000111101
#        Step 4 Str:  0011000001100000101000001011100
#        Step 5 Str:  1111100001010010101000011010100
#        Step 6 Str:  1101100001010010101000011110100
#        Step 7 Str:  1001100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 16.385868787765503
#                   Ratio
# phenotype
# P_epithelial   0.013656
# P_hybrid_high  0.491392
# P_mesenchymal  0.494952
#
# --- 시뮬레이션: 'p53' 로직 제거 (항상 0 출력) ---
#
# --- 노드 'p53'의 Boolean Function ---
#   입력 노드들: 없음 (상수)
#   진리표 (Truth Table): {(): 0}
#   ==> 확인: 이 노드는 입력에 무관하게 항상 '0'을(를) 출력하는 상수 함수입니다 (로직 제거됨).
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.84%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Steady State, Basin 29.80%)
#     State Str:  1001100000110011100000011110000
#   > Attractor ID 2 (Steady State, Basin 1.21%)
#     State Str:  1001100100100011100000011000100
#   > Attractor ID 3 (Cyclic, Length 2, Basin 5.64%)
#     Cycle Start Str:  1101100000110010101000011100100
#        Step 1 Str:  1101100000110010101000011100100
#        Step 2 Str:  1011100101100011100000011010000
#   > Attractor ID 4 (Cyclic, Length 2, Basin 3.76%)
#     Cycle Start Str:  1100100000110010101000011110000
#        Step 1 Str:  1100100000110010101000011110000
#        Step 2 Str:  1011100001110011100100011110000
#   > Attractor ID 5 (Cyclic, Length 2, Basin 4.03%)
#     Cycle Start Str:  1001100000110011100000011100100
#        Step 1 Str:  1001100000110011100000011100100
#        Step 2 Str:  1001100100100011100000011010000
#   > Attractor ID 6 (Cyclic, Length 2, Basin 5.72%)
#     Cycle Start Str:  1101100000110010101000011110100
#        Step 1 Str:  1101100000110010101000011110100
#        Step 2 Str:  1011100001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 18.02614402770996
#                   Ratio
# phenotype
# P_epithelial   0.012091
# P_hybrid_high  0.489483
# P_mesenchymal  0.498427
#
# 노드 로직 제거 분석 결과 저장 완료: ./logic_disruption_results/node_logic_disruption_analysis_results.csv
