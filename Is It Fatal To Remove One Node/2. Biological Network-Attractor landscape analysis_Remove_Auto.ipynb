# %% [markdown]
# ## Attractor Landscape analysis
#
# This is an example of how Boolean network model was analyzed in our paper.
#
# We provide the codes for 'Attractor landscape analysis', 'Perturbation analysis', and 'Analysis of network dynamics' (Please refer to the Method section).

# %%
import numpy as np
import pandas as pd
import itertools
import networkx as nx
import copy
import os
from collections import defaultdict, deque

from pyboolnet.file_exchange import bnet2primes, primes2bnet
from pyboolnet.interaction_graphs import primes2igraph
from pyboolnet.state_transition_graphs import primes2stg
from pyboolnet.attractors import compute_attractors_tarjan

from modules.attractorSim import rand_initial_states, compute_attractor_from_primes, compute_phenotype, Simulation
from modules.printlogic import print_node_logic

# %%
network_dir = './network/'
model_file = network_dir + 'EMT_Network.bnet'
primes = bnet2primes(model_file)
nodeList = list(primes.keys())
graph = primes2igraph(primes)
update_mode = "synchronous"

# nodes_order = sorted(primes.keys())  # 이미 선언된 상태여야 함
nodes_order = sorted(primes.keys())
print("총 노드 수:", len(nodes_order))
print("앞 31개 노드:", nodes_order[:31])

# (붙여넣기용) 자동 마커/phenotype 생성
# --- 위 2) 셀의 코드 전체를 여기에 붙여 넣으면 됨 ---

# --- 시작: phenotype/markers 자동 설정 (복붙해서 기존 phenotype 셀 대신 사용) ---
# nodes_order는 위에서 확인한 primes의 정렬된 노드 리스트

# 1) 마커 자동 찾기: E-cad (E-cadherin 계열)과 ZEB1 계열 노드 이름 검색
def find_node_by_keywords(nodes_order, keywords):
    for n in nodes_order:
        lower = n.lower()
        for kw in keywords:
            if kw.lower() in lower:
                return n
    return None

ecad_candidates = ["ecad", "cdh1", "e-cad", "ecadherin"]
zeb_candidates  = ["zeb1", "zeb"]

Ecad_node = find_node_by_keywords(nodes_order, ecad_candidates)
ZEB_node  = find_node_by_keywords(nodes_order, zeb_candidates)

if not Ecad_node or not ZEB_node:
    raise RuntimeError(f"E-cad 또는 ZEB1 노드를 찾을 수 없음. nodes 예시: {nodes_order[:30]}")

print("Detected markers -> E-cad:", Ecad_node, ", ZEB1:", ZEB_node)

# 2) markers 변수 (노트북의 기존 markers 변수 대체)
markers = [Ecad_node, ZEB_node]

# 3) phenotype 정의: 논문 기준 (Epithelial / Mesenchymal / Hybrid)
# P1..P4은 모든 조합(1/0) 중 논문에서 말한 4개 조합(원하면 이름 바꿔도 됨)
phenotype = {
    'P_epithelial': {Ecad_node:1, ZEB_node:0},   # epithelial (E-cad + / ZEB1 -)
    'P_mesenchymal': {Ecad_node:0, ZEB_node:1},  # mesenchymal (E-cad - / ZEB1 +)
    'P_hybrid_high': {Ecad_node:1, ZEB_node:1},  # hybrid (E-cad + / ZEB1 +)
    'P_hybrid_low' : {Ecad_node:0, ZEB_node:0}   # hybrid (E-cad - / ZEB1 -)
}

# 4) phenotypeAnnot: 숫자 레이블 관례 (논문/분석 용도에 맞게)
# 여기선 epithelial = -1, mesenchymal = +1, hybrid들 = 0 (논문/시각화에서 자주 사용하는 구분)
phenotypeAnnot = {
    'P_epithelial': -1,
    'P_mesenchymal': 1,
    'P_hybrid_high': 0,
    'P_hybrid_low': 0
}

print("phenotype keys:", list(phenotype.keys()))
print("markers:", markers)
# --- 끝 ---


if 2**len(nodeList) >= 100000: num_init = 100000
else:  num_init = 2**len(nodeList)
initState = rand_initial_states(num_init, len(nodeList))
# Out:
# 총 노드 수: 31
# 앞 31개 노드: ['AKT', 'AP1', 'ERK', 'Ecadherin', 'EpCAM', 'GLI', 'GRB2SOS', 'GSK3b', 'IKK', 'MDM2', 'MEK', 'MYC', 'NFKB', 'NOTCH', 'PI3K', 'RAF', 'RAS', 'SMAD23', 'SMAD4', 'Snail', 'TAK1', 'TGFBR', 'TGFb', 'THY1', 'Twist1', 'ZEB1', 'bcatenin', 'miR200', 'miR34', 'p38', 'p53']
# Detected markers -> E-cad: Ecadherin , ZEB1: ZEB1
# phenotype keys: ['P_epithelial', 'P_mesenchymal', 'P_hybrid_high', 'P_hybrid_low']
# markers: ['Ecadherin', 'ZEB1']

# %% [markdown]
# ### Node perturbation analysis

# %%
save_dir = './result/EMT/' 
save_perturbname = save_dir + 'EMT_single_simul_result.csv'

# %%
fix_dict = {'RAS':1}
# allsingles = [{n:1} for n in nodeList] + [{n:0} for n in nodeList]

# %%
fix_dict_tmp = copy.deepcopy(fix_dict) # fix_dict는 {'RAS':1} 인 상태

print(fix_dict_tmp) # 현재 적용할 고정 노드 출력

primes_new, pheno_df, att_ave_pd, attrs_dict = Simulation(fix_dict_tmp, primes, update_mode, initState, phenotype, phenotypeAnnot)   

print(f'attrs_dict={attrs_dict}')


ori_attrs_num = len(attrs_dict)
print(f'어트랙터 개수: {ori_attrs_num}')
# Out:
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**31=2147483648 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.89%)
#     State Str:  1110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.40%)
#     Cycle Start Str:  1001000101100001100000000001101
#        Step 1 Str:  1001000101100001100000000001101
#        Step 2 Str:  0001000101100001100000000001100
#        Step 3 Str:  0001100100100011100000001000100
#        Step 4 Str:  1001100100100011100000001000101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.72%)
#     Cycle Start Str:  1101100001010010101000011110100
#        Step 1 Str:  1101100001010010101000011110100
#        Step 2 Str:  1001100001110011100000011110000
#        Step 3 Str:  1001100000110011100000011110000
#        Step 4 Str:  1001100000110011100000011110001
#        Step 5 Str:  1011000001110001100000000111101
#        Step 6 Str:  0011000001100000101000001011100
#        Step 7 Str:  1111100001010010101000011010100
# --- End of Attractor Listing ---
# Attractor simulation time : 17.345048666000366
#                   Ratio
# phenotype
# P_epithelial   0.013956
# P_hybrid_high  0.497165
# P_mesenchymal  0.488879
# attrs_dict=defaultdict(None, {0: defaultdict(None, {'attractors': ('1110011011111111111111111110010',), 'basinsizes': 89324, 'perc': 0.4888786724462542, 'phenotype': 1}), 1: defaultdict(None, {'attractors': ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), 'basinsizes': 2550, 'perc': 0.013956390384867989, 'phenotype': -1}), 2: defaultdict(None, {'attractors': ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), 'basinsizes': 90838, 'perc': 0.4971649371688778, 'phenotype': 0})})
# 어트랙터 개수: 3

# %% [markdown]
# ### 하나씩 없앤 네트워크 분석

# %%
def remove_char_at_index(s: str, index: int) -> str:
    """
    주어진 문자열에서 특정 인덱스의 문자를 제거합니다.
    """
    if not (0 <= index < len(s)):
        raise IndexError(f"인덱스 {index}가 문자열 길이 {len(s)}의 범위를 벗어납니다.")
    return s[:index] + s[index+1:]

def transform_attractor_for_comparison(attractor_tuple: tuple, removed_node_index: int) -> tuple:
    """
    original attractor 튜플의 각 문자열에서 removed_node_index에 해당하는 문자를 제거하여
    비교를 위한 새로운 튜플을 생성합니다.
    """
    transformed_strings = []
    for s in attractor_tuple:
        transformed_strings.append(remove_char_at_index(s, removed_node_index))
    return tuple(transformed_strings)

def are_cyclic_attractors_identical(attractor1, attractor2):
    """
    두 개의 cyclic attractor 튜플이 순환적으로 동일한지 비교합니다.
    """
    if len(attractor1) != len(attractor2):
        return False

    if not attractor1 or not attractor2: # 빈 튜플인 경우
        return False

    d1 = deque(attractor1)
    
    for _ in range(len(attractor1)):
        if tuple(d1) == attractor2:
            return True
        d1.rotate(1) # 한 칸씩 회전

    return False

def compare_attractors(attr_tuple1, attr_tuple2):
    """
    두 개의 attractor 튜플을 비교하여 동일한지 여부를 반환합니다.
    steady-state와 cyclic attractor를 구분하여 비교합니다.
    """
    len1 = len(attr_tuple1)
    len2 = len(attr_tuple2)

    if len1 == 1 and len2 == 1:
        return attr_tuple1[0] == attr_tuple2[0]
    elif len1 > 1 and len2 > 1:
        # ↓↓↓ 여기가 문제의 발생 원인이었습니다. attr_tuple1, attr_tuple2로 수정했습니다. ↓↓↓
        return are_cyclic_attractors_identical(attr_tuple1, attr_tuple2)
        # ↑↑↑
    else:
        return False

def find_identical_attractors(original_data, new_data, removed_node_index: int):
    """
    original 네트워크와 new 네트워크 간에 동일한 attractor를 찾아 출력합니다.
    original 네트워크의 각 attractor는 removed_node_index에 해당하는 노드를 제거한 후 비교합니다.
    """
    print(f"--- Attractor 비교 결과 (original에서 노드 {removed_node_index} 제거 후) ---")
    found_any_match = False

    for original_key, original_info in original_data.items():
        original_attractor_raw = original_info['attractors']
        
        try:
            if not original_attractor_raw:
                print(f"⚠️ Original {original_key}번 어트랙터 튜플이 비어있습니다. 건너뜁니다.")
                continue
            
            # 모든 문자열의 길이가 removed_node_index보다 길어야만 제거를 시도
            if any(len(s) <= removed_node_index for s in original_attractor_raw):
                 print(f"⚠️ Original {original_key}번 어트랙터 문자열 중 노드 {removed_node_index}를 제거할 수 없는 짧은 문자열이 있습니다. 건너뜁니다.")
                 continue

            original_attractor_transformed = transform_attractor_for_comparison(original_attractor_raw, removed_node_index)
            original_type = "Steady-state" if len(original_attractor_transformed) == 1 else "Cyclic"

        except IndexError as e:
            print(f"⚠️ Original {original_key}번 어트랙터 변형 중 오류 발생 (인덱스 {removed_node_index}): {e}. 이 어트랙터는 건너뜁니다.")
            continue
        
        match_found_for_this_original = False
        
        for new_key, new_info in new_data.items():
            new_attractor = new_info['attractors']
            new_type = "Steady-state" if len(new_attractor) == 1 else "Cyclic"

            if not original_attractor_transformed or not new_attractor:
                continue 
            
            # 변형된 original 어트랙터와 new 어트랙터의 문자열 길이가 다르면 비교하지 않음
            # 모든 문자열이 동일한 길이를 가지는 것을 가정
            if len(original_attractor_transformed[0]) != len(new_attractor[0]):
                continue

            if compare_attractors(original_attractor_transformed, new_attractor):
                print(f"✅ 동일한 attractor를 찾았습니다!")
                print(f"  - Original: {original_key}번 (원본: {original_attractor_raw}, {original_type})")
                print(f"    (노드 {removed_node_index} 제거 후): {original_attractor_transformed}")
                print(f"  - New     : {new_key}번 ({new_type})")
                print(f"    어트랙터: {new_attractor}")
                print("-" * 30)
                found_any_match = True
                match_found_for_this_original = True
                break
        
        if not match_found_for_this_original:
            print(f"❌ Original {original_key}번 어트랙터 (노드 {removed_node_index} 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.")
            print(f"   (노드 제거 전): {original_attractor_raw}")
            print(f"   (노드 제거 후): {original_attractor_transformed}")
            print("-" * 30)

    if not found_any_match:
        print(f"💡 Original과 New 네트워크 사이에 (노드 {removed_node_index} 제거 후) 동일한 attractor를 찾을 수 없습니다.")

# %%
remove_network_dir = './network/biological_network/EMT_Network_'
remove_fix_dict = copy.deepcopy(fix_dict) # fix_dict는 {'RAS':1} 인 상태
remove_update_mode = "synchronous"

for i in range(len(nodes_order)):
    remove_node_now = nodes_order[i]
    print(f'------remove logic of {remove_node_now}------')
    try:
        remove_model_file = remove_network_dir + str(i) + '.bnet'
        remove_primes = bnet2primes(remove_model_file)
        print(remove_fix_dict) # 현재 적용할 고정 노드 출력

        remove_nodeList = list(remove_primes.keys())
        if 2**len(remove_nodeList) >= 100000: remove_num_init = 100000
        else:  remove_num_init = 2**len(remove_nodeList)
        remove_initState = rand_initial_states(remove_num_init, len(remove_nodeList))
        
        reomve_primes_new, remove_pheno_df, remove_att_ave_pd, remove_attrs_dict = Simulation(remove_fix_dict, remove_primes, remove_update_mode, remove_initState, phenotype, phenotypeAnnot)
        # print(f'\nremove_attrs_dict={remove_attrs_dict}\n')

        copy_ori_attrs = copy.deepcopy(attrs_dict)
        copy_remove_attrs = copy.deepcopy(remove_attrs_dict)
        # print(copy_ori_attrs)
        # print(copy_remove_attrs)
        # 기존: find_identical_attractors(copy_ori_attrs, remove_attrs_dict, i)
        try: # find_identical_attractors 내부에서 발생하는 예외를 더 상세히 잡기 위함
            find_identical_attractors(copy_ori_attrs, remove_attrs_dict, i)
        except Exception as e:
            print(f"DEBUG: find_identical_attractors 호출 중 예외 발생: {type(e).__name__}: {e}")
            raise # 이 예외를 다시 상위 try-except 블록으로 전달하여, 사용자 코드의 catch 문으로 가게 합니다.
        
        
    except:
        print("--현재 로직은 Phenotype Node 또는 가장 상위 Node 입니다.--")
# Out:
# ------remove logic of AKT------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.54%)
#     State Str:  110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.60%)
#     Cycle Start Str:  001000101100001100000000001101
#        Step 1 Str:  001000101100001100000000001101
#        Step 2 Str:  001000101100001100000000001100
#        Step 3 Str:  001100100100011100000001000100
#        Step 4 Str:  001100100100011100000011000101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 48.86%)
#     Cycle Start Str:  011000001110001100000000111101
#        Step 1 Str:  011000001110001100000000111101
#        Step 2 Str:  011000001100000101000001011100
#        Step 3 Str:  111100001010010101000011010100
#        Step 4 Str:  101100001010010101000011110100
#        Step 5 Str:  001100001110011100000011110000
#        Step 6 Str:  001100000110011100000011110000
#        Step 7 Str:  001100000110011100000011110001
# --- End of Attractor Listing ---
# Attractor simulation time : 15.491191864013672
#                   Ratio
# phenotype
# P_epithelial   0.015991
# P_hybrid_high  0.488613
# P_mesenchymal  0.495396
# --- Attractor 비교 결과 (original에서 노드 0 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 0 제거 후): ('110011011111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('110011011111111111111111110010',)
# ------------------------------
# ❌ Original 1번 어트랙터 (노드 0 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101')
#    (노드 제거 후): ('001000101100001100000000001101', '001000101100001100000000001100', '001100100100011100000001000100', '001100100100011100000001000101')
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 2번 (원본: ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), Cyclic)
#     (노드 0 제거 후): ('101100001010010101000011110100', '001100001110011100000011110000', '001100000110011100000011110000', '001100000110011100000011110001', '011000001110001100000000111101', '011000001100000101000001011100', '111100001010010101000011010100')
#   - New     : 2번 (Cyclic)
#     어트랙터: ('011000001110001100000000111101', '011000001100000101000001011100', '111100001010010101000011010100', '101100001010010101000011110100', '001100001110011100000011110000', '001100000110011100000011110000', '001100000110011100000011110001')
# ------------------------------
# ------remove logic of AP1------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.54%)
#     State Str:  110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.36%)
#     Cycle Start Str:  101100100100011100000001000101
#        Step 1 Str:  101100100100011100000001000101
#        Step 2 Str:  101000101100001100000000001101
#        Step 3 Str:  001000101100001100000000001100
#        Step 4 Str:  001100100100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.10%)
#     Cycle Start Str:  101100000110011100000011110000
#        Step 1 Str:  101100000110011100000011110000
#        Step 2 Str:  101100000110011100000011110001
#        Step 3 Str:  111000001110001100000000111101
#        Step 4 Str:  011000001100000101000001011100
#        Step 5 Str:  111100001010010101000011010100
#        Step 6 Str:  101100001010010101000011110100
#        Step 7 Str:  101000001110011100000011110000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.76904010772705
#                   Ratio
# phenotype
# P_epithelial   0.013604
# P_hybrid_high  0.490989
# P_mesenchymal  0.495406
# --- Attractor 비교 결과 (original에서 노드 1 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 1 제거 후): ('110011011111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('110011011111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 1 제거 후): ('101000101100001100000000001101', '001000101100001100000000001100', '001100100100011100000001000100', '101100100100011100000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('101100100100011100000001000101', '101000101100001100000000001101', '001000101100001100000000001100', '001100100100011100000001000100')
# ------------------------------
# ❌ Original 2번 어트랙터 (노드 1 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100')
#    (노드 제거 후): ('101100001010010101000011110100', '101100001110011100000011110000', '101100000110011100000011110000', '101100000110011100000011110001', '111000001110001100000000111101', '011000001100000101000001011100', '111100001010010101000011010100')
# ------------------------------
# ------remove logic of ERK------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.71%)
#     State Str:  110011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 3.21%)
#     Cycle Start Str:  101100100100011100000001000101
#        Step 1 Str:  101100100100011100000001000101
#        Step 2 Str:  101000101100001100000000001101
#        Step 3 Str:  001000101100001100000000001100
#        Step 4 Str:  001100100100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 6, Basin 3.04%)
#     Cycle Start Str:  101100000110011100000011100101
#        Step 1 Str:  101100000110011100000011100101
#        Step 2 Str:  101000101100001100000000011101
#        Step 3 Str:  001000001100000101000001001100
#        Step 4 Str:  111000101010010101000001010100
#        Step 5 Str:  101100001110011100000011100100
#        Step 6 Str:  101100100100011100000011010000
#   > Attractor ID 3 (Cyclic, Length 5, Basin 44.03%)
#     Cycle Start Str:  101100000110011100000011110100
#        Step 1 Str:  101100000110011100000011110100
#        Step 2 Str:  101100000110011100000011110001
#        Step 3 Str:  111000001110000101000001111101
#        Step 4 Str:  011000001000000101000001011100
#        Step 5 Str:  101100001110011100000011010100
# --- End of Attractor Listing ---
# Attractor simulation time : 17.477413415908813
#                   Ratio
# phenotype
# P_epithelial   0.062542
# P_hybrid_high  0.440323
# P_mesenchymal  0.497135
# --- Attractor 비교 결과 (original에서 노드 2 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 2 제거 후): ('110011011111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('110011011111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 2 제거 후): ('101000101100001100000000001101', '001000101100001100000000001100', '001100100100011100000001000100', '101100100100011100000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('101100100100011100000001000101', '101000101100001100000000001101', '001000101100001100000000001100', '001100100100011100000001000100')
# ------------------------------
# ❌ Original 2번 어트랙터 (노드 2 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100')
#    (노드 제거 후): ('111100001010010101000011110100', '101100001110011100000011110000', '101100000110011100000011110000', '101100000110011100000011110001', '101000001110001100000000111101', '001000001100000101000001011100', '111100001010010101000011010100')
# ------------------------------
# ------remove logic of Ecadherin------
# ERROR failed to run bnet2primes: cmd=/data/student/anaconda3/envs/python_3_9/lib/python3.9/site-packages/pyboolnet/binaries/BNetToPrime/BNetToPrime_linux64, return_code=1, out=b'{'
# {'RAS': 1}
# --현재 로직은 Phenotype Node 또는 가장 상위 Node 입니다.--
# ------remove logic of EpCAM------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.45%)
#     State Str:  111011011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.37%)
#     Cycle Start Str:  100100100100011100000001000101
#        Step 1 Str:  100100100100011100000001000101
#        Step 2 Str:  100100101100001100000000001101
#        Step 3 Str:  000100101100001100000000001100
#        Step 4 Str:  000100100100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.19%)
#     Cycle Start Str:  101100001110001100000000111101
#        Step 1 Str:  101100001110001100000000111101
#        Step 2 Str:  001100001100000101000001011100
#        Step 3 Str:  111100001010010101000011010100
#        Step 4 Str:  110100001010010101000011110100
#        Step 5 Str:  100100001110011100000011110000
#        Step 6 Str:  100100000110011100000011110000
#        Step 7 Str:  100100000110011100000011110001
# --- End of Attractor Listing ---
# Attractor simulation time : 15.120096206665039
#                   Ratio
# phenotype
# P_epithelial   0.013665
# P_hybrid_high  0.491876
# P_mesenchymal  0.494459
# --- Attractor 비교 결과 (original에서 노드 4 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 4 제거 후): ('111011011111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111011011111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 4 제거 후): ('100100101100001100000000001101', '000100101100001100000000001100', '000100100100011100000001000100', '100100100100011100000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('100100100100011100000001000101', '100100101100001100000000001101', '000100101100001100000000001100', '000100100100011100000001000100')
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 2번 (원본: ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), Cyclic)
#     (노드 4 제거 후): ('110100001010010101000011110100', '100100001110011100000011110000', '100100000110011100000011110000', '100100000110011100000011110001', '101100001110001100000000111101', '001100001100000101000001011100', '111100001010010101000011010100')
#   - New     : 2번 (Cyclic)
#     어트랙터: ('101100001110001100000000111101', '001100001100000101000001011100', '111100001010010101000011010100', '110100001010010101000011110100', '100100001110011100000011110000', '100100000110011100000011110000', '100100000110011100000011110001')
# ------------------------------
# ------remove logic of GLI------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 48.90%)
#     State Str:  111001011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.63%)
#     Cycle Start Str:  100110100100011100000001000101
#        Step 1 Str:  100110100100011100000001000101
#        Step 2 Str:  100100101100001100000000001101
#        Step 3 Str:  000100101100001100000000001100
#        Step 4 Str:  000110100100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.47%)
#     Cycle Start Str:  101100001110001100000000111101
#        Step 1 Str:  101100001110001100000000111101
#        Step 2 Str:  001100001100000101000001011100
#        Step 3 Str:  111110001010010101000011010100
#        Step 4 Str:  110110001010010101000011110100
#        Step 5 Str:  100110001110011100000011110000
#        Step 6 Str:  100110000110011100000011110000
#        Step 7 Str:  100110000110011100000011110001
# --- End of Attractor Listing ---
# Attractor simulation time : 16.350139379501343
#                   Ratio
# phenotype
# P_epithelial   0.016257
# P_hybrid_high  0.494750
# P_mesenchymal  0.488993
# --- Attractor 비교 결과 (original에서 노드 5 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 5 제거 후): ('111001011111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001011111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 5 제거 후): ('100100101100001100000000001101', '000100101100001100000000001100', '000110100100011100000001000100', '100110100100011100000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('100110100100011100000001000101', '100100101100001100000000001101', '000100101100001100000000001100', '000110100100011100000001000100')
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 2번 (원본: ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), Cyclic)
#     (노드 5 제거 후): ('110110001010010101000011110100', '100110001110011100000011110000', '100110000110011100000011110000', '100110000110011100000011110001', '101100001110001100000000111101', '001100001100000101000001011100', '111110001010010101000011010100')
#   - New     : 2번 (Cyclic)
#     어트랙터: ('101100001110001100000000111101', '001100001100000101000001011100', '111110001010010101000011010100', '110110001010010101000011110100', '100110001110011100000011110000', '100110000110011100000011110000', '100110000110011100000011110001')
# ------------------------------
# ------remove logic of GRB2SOS------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.34%)
#     State Str:  111001011111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.46%)
#     Cycle Start Str:  100110100100011100000001000101
#        Step 1 Str:  100110100100011100000001000101
#        Step 2 Str:  100100101100001100000000001101
#        Step 3 Str:  000100101100001100000000001100
#        Step 4 Str:  000110100100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.19%)
#     Cycle Start Str:  101100001110001100000000111101
#        Step 1 Str:  101100001110001100000000111101
#        Step 2 Str:  001100001100000101000001011100
#        Step 3 Str:  111110001010010101000011010100
#        Step 4 Str:  110110001010010101000011110100
#        Step 5 Str:  100110001110011100000011110000
#        Step 6 Str:  100110000110011100000011110000
#        Step 7 Str:  100110000110011100000011110001
# --- End of Attractor Listing ---
# Attractor simulation time : 16.422807216644287
#                   Ratio
# phenotype
# P_epithelial   0.014643
# P_hybrid_high  0.491943
# P_mesenchymal  0.493414
# --- Attractor 비교 결과 (original에서 노드 6 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 6 제거 후): ('111001011111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001011111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 6 제거 후): ('100100101100001100000000001101', '000100101100001100000000001100', '000110100100011100000001000100', '100110100100011100000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('100110100100011100000001000101', '100100101100001100000000001101', '000100101100001100000000001100', '000110100100011100000001000100')
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 2번 (원본: ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), Cyclic)
#     (노드 6 제거 후): ('110110001010010101000011110100', '100110001110011100000011110000', '100110000110011100000011110000', '100110000110011100000011110001', '101100001110001100000000111101', '001100001100000101000001011100', '111110001010010101000011010100')
#   - New     : 2번 (Cyclic)
#     어트랙터: ('101100001110001100000000111101', '001100001100000101000001011100', '111110001010010101000011010100', '110110001010010101000011110100', '100110001110011100000011110000', '100110000110011100000011110000', '100110000110011100000011110001')
# ------------------------------
# ------remove logic of GSK3b------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.49%)
#     State Str:  111001111111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 2.69%)
#     Cycle Start Str:  100110000100011100000001000101
#        Step 1 Str:  100110000100011100000001000101
#        Step 2 Str:  100100001100001100000000001101
#        Step 3 Str:  000100001100001100000000001100
#        Step 4 Str:  000110000100011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 47.82%)
#     Cycle Start Str:  101100001110001100000000111101
#        Step 1 Str:  101100001110001100000000111101
#        Step 2 Str:  001100001100000101000001011100
#        Step 3 Str:  111110001010010101000011010100
#        Step 4 Str:  110110001010010101000011110100
#        Step 5 Str:  100110001110011100000011110000
#        Step 6 Str:  100110000110011100000011110000
#        Step 7 Str:  100110000110011100000011110001
# --- End of Attractor Listing ---
# Attractor simulation time : 15.273296356201172
#                   Ratio
# phenotype
# P_epithelial   0.026876
# P_hybrid_high  0.478231
# P_mesenchymal  0.494894
# --- Attractor 비교 결과 (original에서 노드 7 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 7 제거 후): ('111001111111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001111111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 7 제거 후): ('100100001100001100000000001101', '000100001100001100000000001100', '000110000100011100000001000100', '100110000100011100000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('100110000100011100000001000101', '100100001100001100000000001101', '000100001100001100000000001100', '000110000100011100000001000100')
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 2번 (원본: ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), Cyclic)
#     (노드 7 제거 후): ('110110001010010101000011110100', '100110001110011100000011110000', '100110000110011100000011110000', '100110000110011100000011110001', '101100001110001100000000111101', '001100001100000101000001011100', '111110001010010101000011010100')
#   - New     : 2번 (Cyclic)
#     어트랙터: ('101100001110001100000000111101', '001100001100000101000001011100', '111110001010010101000011010100', '110110001010010101000011110100', '100110001110011100000011110000', '100110000110011100000011110000', '100110000110011100000011110001')
# ------------------------------
# ------remove logic of IKK------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.54%)
#     State Str:  111001101111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.32%)
#     Cycle Start Str:  000110010100011100000001000100
#        Step 1 Str:  000110010100011100000001000100
#        Step 2 Str:  100110010100011100000001000101
#        Step 3 Str:  100100011100001100000000001101
#        Step 4 Str:  000100011100001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.14%)
#     Cycle Start Str:  101100001110001100000000111101
#        Step 1 Str:  101100001110001100000000111101
#        Step 2 Str:  001100001100000101000001011100
#        Step 3 Str:  111110001010010101000011010100
#        Step 4 Str:  110110001010010101000011110100
#        Step 5 Str:  100110001110011100000011110000
#        Step 6 Str:  100110000110011100000011110000
#        Step 7 Str:  100110000110011100000011110001
# --- End of Attractor Listing ---
# Attractor simulation time : 15.567405700683594
#                   Ratio
# phenotype
# P_epithelial   0.013171
# P_hybrid_high  0.491417
# P_mesenchymal  0.495412
# --- Attractor 비교 결과 (original에서 노드 8 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 8 제거 후): ('111001101111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 8 제거 후): ('100100011100001100000000001101', '000100011100001100000000001100', '000110010100011100000001000100', '100110010100011100000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('000110010100011100000001000100', '100110010100011100000001000101', '100100011100001100000000001101', '000100011100001100000000001100')
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 2번 (원본: ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), Cyclic)
#     (노드 8 제거 후): ('110110001010010101000011110100', '100110001110011100000011110000', '100110000110011100000011110000', '100110000110011100000011110001', '101100001110001100000000111101', '001100001100000101000001011100', '111110001010010101000011010100')
#   - New     : 2번 (Cyclic)
#     어트랙터: ('101100001110001100000000111101', '001100001100000101000001011100', '111110001010010101000011010100', '110110001010010101000011110100', '100110001110011100000011110000', '100110000110011100000011110000', '100110000110011100000011110001')
# ------------------------------
# ------remove logic of MDM2------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.46%)
#     State Str:  111001101111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 2, Basin 2.88%)
#     Cycle Start Str:  101100000100001100100000111100
#        Step 1 Str:  101100000100001100100000111100
#        Step 2 Str:  000010000110010101000011010001
#   > Attractor ID 2 (Cyclic, Length 2, Basin 5.60%)
#     Cycle Start Str:  101100010100001100000000011100
#        Step 1 Str:  101100010100001100000000011100
#        Step 2 Str:  000110000110010101000011000101
#   > Attractor ID 3 (Cyclic, Length 2, Basin 1.33%)
#     Cycle Start Str:  100100010100001100000000001100
#        Step 1 Str:  100100010100001100000000001100
#        Step 2 Str:  000110010100011100000011000101
#   > Attractor ID 4 (Cyclic, Length 2, Basin 37.80%)
#     Cycle Start Str:  000110000110010101000011010101
#        Step 1 Str:  000110000110010101000011010101
#        Step 2 Str:  101100000100001100000000111100
#   > Attractor ID 5 (Cyclic, Length 2, Basin 2.94%)
#     Cycle Start Str:  100100010100001100000000011100
#        Step 1 Str:  100100010100001100000000011100
#        Step 2 Str:  000110000110011100000011000101
# --- End of Attractor Listing ---
# Attractor simulation time : 17.45892596244812
#                   Ratio
# phenotype
# P_epithelial   0.098587
# P_hybrid_high  0.406834
# P_mesenchymal  0.494580
# --- Attractor 비교 결과 (original에서 노드 9 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 9 제거 후): ('111001101111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111110010',)
# ------------------------------
# ❌ Original 1번 어트랙터 (노드 9 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101')
#    (노드 제거 후): ('100100010100001100000000001101', '000100010100001100000000001100', '000110010100011100000001000100', '100110010100011100000001000101')
# ------------------------------
# ❌ Original 2번 어트랙터 (노드 9 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100')
#    (노드 제거 후): ('110110000010010101000011110100', '100110000110011100000011110000', '100110000110011100000011110000', '100110000110011100000011110001', '101100000110001100000000111101', '001100000100000101000001011100', '111110000010010101000011010100')
# ------------------------------
# ------remove logic of MEK------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.64%)
#     State Str:  111001101111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 0.69%)
#     Cycle Start Str:  000100010100001100000000001100
#        Step 1 Str:  000100010100001100000000001100
#        Step 2 Str:  000110010000011100000001000100
#        Step 3 Str:  100110010000011100000001000101
#        Step 4 Str:  100100010100001100000000001101
#   > Attractor ID 2 (Cyclic, Length 5, Basin 49.66%)
#     Cycle Start Str:  101110000110011100000011110100
#        Step 1 Str:  101110000110011100000011110100
#        Step 2 Str:  110110000010010101000011110100
#        Step 3 Str:  101110000110011100000011110001
#        Step 4 Str:  111100000110000101000001111100
#        Step 5 Str:  110100000110010101000011010100
# --- End of Attractor Listing ---
# Attractor simulation time : 14.62097978591919
#                   Ratio
# phenotype
# P_epithelial   0.006944
# P_hybrid_high  0.496606
# P_mesenchymal  0.496450
# --- Attractor 비교 결과 (original에서 노드 10 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 10 제거 후): ('111001101111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 10 제거 후): ('100100010100001100000000001101', '000100010100001100000000001100', '000110010000011100000001000100', '100110010000011100000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('000100010100001100000000001100', '000110010000011100000001000100', '100110010000011100000001000101', '100100010100001100000000001101')
# ------------------------------
# ❌ Original 2번 어트랙터 (노드 10 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100')
#    (노드 제거 후): ('110110000110010101000011110100', '100110000110011100000011110000', '100110000010011100000011110000', '100110000010011100000011110001', '101100000110001100000000111101', '001100000100000101000001011100', '111110000110010101000011010100')
# ------------------------------
# ------remove logic of MYC------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.05%)
#     State Str:  111001101111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.37%)
#     Cycle Start Str:  100110010010011100000001000101
#        Step 1 Str:  100110010010011100000001000101
#        Step 2 Str:  100100010110001100000000001101
#        Step 3 Str:  000100010110001100000000001100
#        Step 4 Str:  000110010010011100000001000100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.58%)
#     Cycle Start Str:  001100000110000101000001011100
#        Step 1 Str:  001100000110000101000001011100
#        Step 2 Str:  111110000100010101000011010100
#        Step 3 Str:  110110000100010101000011110100
#        Step 4 Str:  100110000110011100000011110000
#        Step 5 Str:  100110000010011100000011110000
#        Step 6 Str:  100110000010011100000011110001
#        Step 7 Str:  101100000110001100000000111101
# --- End of Attractor Listing ---
# Attractor simulation time : 16.033150911331177
#                   Ratio
# phenotype
# P_epithelial   0.013686
# P_hybrid_high  0.495808
# P_mesenchymal  0.490506
# --- Attractor 비교 결과 (original에서 노드 11 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 11 제거 후): ('111001101111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 11 제거 후): ('100100010110001100000000001101', '000100010110001100000000001100', '000110010010011100000001000100', '100110010010011100000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('100110010010011100000001000101', '100100010110001100000000001101', '000100010110001100000000001100', '000110010010011100000001000100')
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 2번 (원본: ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), Cyclic)
#     (노드 11 제거 후): ('110110000100010101000011110100', '100110000110011100000011110000', '100110000010011100000011110000', '100110000010011100000011110001', '101100000110001100000000111101', '001100000110000101000001011100', '111110000100010101000011010100')
#   - New     : 2번 (Cyclic)
#     어트랙터: ('001100000110000101000001011100', '111110000100010101000011010100', '110110000100010101000011110100', '100110000110011100000011110000', '100110000010011100000011110000', '100110000010011100000011110001', '101100000110001100000000111101')
# ------------------------------
# ------remove logic of NFKB------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.69%)
#     State Str:  111001101111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.32%)
#     Cycle Start Str:  000110010010011100000001000100
#        Step 1 Str:  000110010010011100000001000100
#        Step 2 Str:  100110010010011100000001000101
#        Step 3 Str:  100100010110001100000000001101
#        Step 4 Str:  000100010110001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 48.99%)
#     Cycle Start Str:  110110000101010101000011110100
#        Step 1 Str:  110110000101010101000011110100
#        Step 2 Str:  100110000111011100000011110000
#        Step 3 Str:  100110000011011100000011110000
#        Step 4 Str:  100110000011011100000011110001
#        Step 5 Str:  101100000111001100000000111101
#        Step 6 Str:  001100000110000101000001011100
#        Step 7 Str:  111110000101010101000011010100
# --- End of Attractor Listing ---
# Attractor simulation time : 15.626198291778564
#                   Ratio
# phenotype
# P_epithelial   0.013206
# P_hybrid_high  0.489925
# P_mesenchymal  0.496869
# --- Attractor 비교 결과 (original에서 노드 12 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 12 제거 후): ('111001101111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 12 제거 후): ('100100010110001100000000001101', '000100010110001100000000001100', '000110010010011100000001000100', '100110010010011100000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('000110010010011100000001000100', '100110010010011100000001000101', '100100010110001100000000001101', '000100010110001100000000001100')
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 2번 (원본: ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), Cyclic)
#     (노드 12 제거 후): ('110110000101010101000011110100', '100110000111011100000011110000', '100110000011011100000011110000', '100110000011011100000011110001', '101100000111001100000000111101', '001100000110000101000001011100', '111110000101010101000011010100')
#   - New     : 2번 (Cyclic)
#     어트랙터: ('110110000101010101000011110100', '100110000111011100000011110000', '100110000011011100000011110000', '100110000011011100000011110001', '101100000111001100000000111101', '001100000110000101000001011100', '111110000101010101000011010100')
# ------------------------------
# ------remove logic of NOTCH------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 46.71%)
#     State Str:  111001101111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 2.56%)
#     Cycle Start Str:  100100010110001100000000001101
#        Step 1 Str:  100100010110001100000000001101
#        Step 2 Str:  000100010110001100000000001100
#        Step 3 Str:  000110010010011100000001000100
#        Step 4 Str:  100110010010011100000001000101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 50.73%)
#     Cycle Start Str:  110110000101010101000011110100
#        Step 1 Str:  110110000101010101000011110100
#        Step 2 Str:  100110000111011100000011110000
#        Step 3 Str:  100110000011011100000011110000
#        Step 4 Str:  100110000011011100000011110001
#        Step 5 Str:  101100000111001100000000111101
#        Step 6 Str:  001100000110000101000001011100
#        Step 7 Str:  111110000101010101000011010100
# --- End of Attractor Listing ---
# Attractor simulation time : 16.27714514732361
#                   Ratio
# phenotype
# P_epithelial   0.025609
# P_hybrid_high  0.507319
# P_mesenchymal  0.467072
# --- Attractor 비교 결과 (original에서 노드 13 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 13 제거 후): ('111001101111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 13 제거 후): ('100100010110001100000000001101', '000100010110001100000000001100', '000110010010011100000001000100', '100110010010011100000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('100100010110001100000000001101', '000100010110001100000000001100', '000110010010011100000001000100', '100110010010011100000001000101')
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 2번 (원본: ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), Cyclic)
#     (노드 13 제거 후): ('110110000101010101000011110100', '100110000111011100000011110000', '100110000011011100000011110000', '100110000011011100000011110001', '101100000111001100000000111101', '001100000110000101000001011100', '111110000101010101000011010100')
#   - New     : 2번 (Cyclic)
#     어트랙터: ('110110000101010101000011110100', '100110000111011100000011110000', '100110000011011100000011110000', '100110000011011100000011110001', '101100000111001100000000111101', '001100000110000101000001011100', '111110000101010101000011010100')
# ------------------------------
# ------remove logic of PI3K------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.25%)
#     State Str:  111001101111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.29%)
#     Cycle Start Str:  100110010010001100000001000100
#        Step 1 Str:  100110010010001100000001000100
#        Step 2 Str:  100110010010001100000011000101
#        Step 3 Str:  000100010110001100000000001101
#        Step 4 Str:  000100010110001100000000001100
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.46%)
#     Cycle Start Str:  001100000110000101000001011100
#        Step 1 Str:  001100000110000101000001011100
#        Step 2 Str:  111110000101000101000011010100
#        Step 3 Str:  110110000101000101000011110100
#        Step 4 Str:  100110000111001100000011110000
#        Step 5 Str:  100110000011001100000011110000
#        Step 6 Str:  100110000011001100000011110001
#        Step 7 Str:  001100000111001100000000111101
# --- End of Attractor Listing ---
# Attractor simulation time : 16.30408477783203
#                   Ratio
# phenotype
# P_epithelial   0.012864
# P_hybrid_high  0.494645
# P_mesenchymal  0.492491
# --- Attractor 비교 결과 (original에서 노드 14 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 14 제거 후): ('111001101111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111110010',)
# ------------------------------
# ❌ Original 1번 어트랙터 (노드 14 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101')
#    (노드 제거 후): ('100100010110001100000000001101', '000100010110001100000000001100', '000110010010001100000001000100', '100110010010001100000001000101')
# ------------------------------
# ❌ Original 2번 어트랙터 (노드 14 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100')
#    (노드 제거 후): ('110110000101000101000011110100', '100110000111001100000011110000', '100110000011001100000011110000', '100110000011001100000011110001', '101100000111001100000000111101', '001100000110000101000001011100', '111110000101000101000011010100')
# ------------------------------
# ------remove logic of RAF------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.03%)
#     State Str:  111001101111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 2.34%)
#     Cycle Start Str:  000100010110000100000000001100
#        Step 1 Str:  000100010110000100000000001100
#        Step 2 Str:  000110010010001100000001000100
#        Step 3 Str:  100110010010001100000001000101
#        Step 4 Str:  100100010110000100000000001101
#   > Attractor ID 2 (Cyclic, Length 6, Basin 37.40%)
#     Cycle Start Str:  100110000111001100000011110100
#        Step 1 Str:  100110000111001100000011110100
#        Step 2 Str:  100110000011001100000011110000
#        Step 3 Str:  100110000011001100000011110001
#        Step 4 Str:  101100000111000100000000111101
#        Step 5 Str:  001100000100000101000001011100
#        Step 6 Str:  110110000101001101000011010100
#   > Attractor ID 3 (Cyclic, Length 3, Basin 11.24%)
#     Cycle Start Str:  000110000001001101000011010100
#        Step 1 Str:  000110000001001101000011010100
#        Step 2 Str:  100110000111001100000011110101
#        Step 3 Str:  101100000110000100000000111100
# --- End of Attractor Listing ---
# Attractor simulation time : 16.723536014556885
#                   Ratio
# phenotype
# P_epithelial   0.023418
# P_hybrid_high  0.486330
# P_mesenchymal  0.490252
# --- Attractor 비교 결과 (original에서 노드 15 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 15 제거 후): ('111001101111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 15 제거 후): ('100100010110000100000000001101', '000100010110000100000000001100', '000110010010001100000001000100', '100110010010001100000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('000100010110000100000000001100', '000110010010001100000001000100', '100110010010001100000001000101', '100100010110000100000000001101')
# ------------------------------
# ❌ Original 2번 어트랙터 (노드 15 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100')
#    (노드 제거 후): ('110110000101001101000011110100', '100110000111001100000011110000', '100110000011001100000011110000', '100110000011001100000011110001', '101100000111000100000000111101', '001100000110000101000001011100', '111110000101001101000011010100')
# ------------------------------
# ------remove logic of RAS------
# ERROR failed to run bnet2primes: cmd=/data/student/anaconda3/envs/python_3_9/lib/python3.9/site-packages/pyboolnet/binaries/BNetToPrime/BNetToPrime_linux64, return_code=1, out=b'{'
# {'RAS': 1}
# --현재 로직은 Phenotype Node 또는 가장 상위 Node 입니다.--
# ------remove logic of SMAD23------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.24%)
#     State Str:  111001101111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 2.69%)
#     Cycle Start Str:  000100010110000110000000001100
#        Step 1 Str:  000100010110000110000000001100
#        Step 2 Str:  000110010010001110000001000100
#        Step 3 Str:  100110010010001110000001000101
#        Step 4 Str:  100100010110000110000000001101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 48.07%)
#     Cycle Start Str:  110110000101001011000011110100
#        Step 1 Str:  110110000101001011000011110100
#        Step 2 Str:  100110000111001110000011110000
#        Step 3 Str:  100110000011001110000011110000
#        Step 4 Str:  100110000011001110000011110001
#        Step 5 Str:  101100000111000110000000111101
#        Step 6 Str:  001100000110000011000001011100
#        Step 7 Str:  111110000101001011000011010100
# --- End of Attractor Listing ---
# Attractor simulation time : 16.100246906280518
#                   Ratio
# phenotype
# P_epithelial   0.026915
# P_hybrid_high  0.480668
# P_mesenchymal  0.492417
# --- Attractor 비교 결과 (original에서 노드 17 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 17 제거 후): ('111001101111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 17 제거 후): ('100100010110000110000000001101', '000100010110000110000000001100', '000110010010001110000001000100', '100110010010001110000001000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('000100010110000110000000001100', '000110010010001110000001000100', '100110010010001110000001000101', '100100010110000110000000001101')
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 2번 (원본: ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), Cyclic)
#     (노드 17 제거 후): ('110110000101001011000011110100', '100110000111001110000011110000', '100110000011001110000011110000', '100110000011001110000011110001', '101100000111000110000000111101', '001100000110000011000001011100', '111110000101001011000011010100')
#   - New     : 2번 (Cyclic)
#     어트랙터: ('110110000101001011000011110100', '100110000111001110000011110000', '100110000011001110000011110000', '100110000011001110000011110001', '101100000111000110000000111101', '001100000110000011000001011100', '111110000101001011000011010100')
# ------------------------------
# ------remove logic of SMAD4------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.98%)
#     State Str:  111001101111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 2.68%)
# ...
#     어트랙터: ('111001101111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 24 제거 후): ('100100010110000110000000001101', '000100010110000110000000001100', '000110010010001110000000000100', '100110010010001110000000000101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('000110010010001110000000000100', '100110010010001110000000000101', '100100010110000110000000001101', '000100010110000110000000001100')
# ------------------------------
# ❌ Original 2번 어트랙터 (노드 24 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100')
#    (노드 제거 후): ('110110000101001010100001110100', '100110000111001110000001110000', '100110000011001110000001110000', '100110000011001110000001110001', '101100000111000110000000111101', '001100000110000010100000011100', '111110000101001010100001010100')
# ------------------------------
# ------remove logic of ZEB1------
# ERROR failed to run bnet2primes: cmd=/data/student/anaconda3/envs/python_3_9/lib/python3.9/site-packages/pyboolnet/binaries/BNetToPrime/BNetToPrime_linux64, return_code=1, out=b'{'
# {'RAS': 1}
# --현재 로직은 Phenotype Node 또는 가장 상위 Node 입니다.--
# ------remove logic of bcatenin------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.53%)
#     State Str:  111001101111111111111111110010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 2.66%)
#     Cycle Start Str:  100100010110000110000000001101
#        Step 1 Str:  100100010110000110000000001101
#        Step 2 Str:  000100010110000110000000001100
#        Step 3 Str:  000110010010001110000000100100
#        Step 4 Str:  100110010010001110000000100101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 47.81%)
#     Cycle Start Str:  100110000011001110000001110001
#        Step 1 Str:  100110000011001110000001110001
#        Step 2 Str:  101100000111000110000000011101
#        Step 3 Str:  001100000110000010100000101100
#        Step 4 Str:  111110000101001010100001100100
#        Step 5 Str:  110110000101001010100001110100
#        Step 6 Str:  100110000111001110000001110000
#        Step 7 Str:  100110000011001110000001110000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.840271711349487
#                   Ratio
# phenotype
# P_epithelial   0.026566
# P_hybrid_high  0.478123
# P_mesenchymal  0.495312
# --- Attractor 비교 결과 (original에서 노드 26 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 26 제거 후): ('111001101111111111111111110010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111110010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 26 제거 후): ('100100010110000110000000001101', '000100010110000110000000001100', '000110010010001110000000100100', '100110010010001110000000100101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('100100010110000110000000001101', '000100010110000110000000001100', '000110010010001110000000100100', '100110010010001110000000100101')
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 2번 (원본: ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), Cyclic)
#     (노드 26 제거 후): ('110110000101001010100001110100', '100110000111001110000001110000', '100110000011001110000001110000', '100110000011001110000001110001', '101100000111000110000000011101', '001100000110000010100000101100', '111110000101001010100001100100')
#   - New     : 2번 (Cyclic)
#     어트랙터: ('100110000011001110000001110001', '101100000111000110000000011101', '001100000110000010100000101100', '111110000101001010100001100100', '110110000101001010100001110100', '100110000111001110000001110000', '100110000011001110000001110000')
# ------------------------------
# ------remove logic of miR200------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.41%)
#     State Str:  111001101111111111111111111010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.46%)
#     Cycle Start Str:  100100010110000110000000000101
#        Step 1 Str:  100100010110000110000000000101
#        Step 2 Str:  000100010110000110000000000100
#        Step 3 Str:  000110010010001110000000100100
#        Step 4 Str:  100110010010001110000000100101
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.13%)
#     Cycle Start Str:  100110000111001110000001111000
#        Step 1 Str:  100110000111001110000001111000
#        Step 2 Str:  100110000011001110000001111000
#        Step 3 Str:  100110000011001110000001111001
#        Step 4 Str:  101100000111000110000000001101
#        Step 5 Str:  001100000110000010100000101100
#        Step 6 Str:  111110000101001010100001111100
#        Step 7 Str:  110100000101001010100001111100
# --- End of Attractor Listing ---
# Attractor simulation time : 15.222417116165161
#                   Ratio
# phenotype
# P_epithelial   0.014578
# P_hybrid_high  0.491317
# P_mesenchymal  0.494105
# --- Attractor 비교 결과 (original에서 노드 27 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 27 제거 후): ('111001101111111111111111111010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111111010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 27 제거 후): ('100100010110000110000000000101', '000100010110000110000000000100', '000110010010001110000000100100', '100110010010001110000000100101')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('100100010110000110000000000101', '000100010110000110000000000100', '000110010010001110000000100100', '100110010010001110000000100101')
# ------------------------------
# ❌ Original 2번 어트랙터 (노드 27 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100')
#    (노드 제거 후): ('110110000101001010100001111100', '100110000111001110000001111000', '100110000011001110000001111000', '100110000011001110000001111001', '101100000111000110000000011101', '001100000110000010100000101100', '111110000101001010100001101100')
# ------------------------------
# ------remove logic of miR34------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.22%)
#     State Str:  111001101111111111111111111010
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.40%)
#     Cycle Start Str:  100100010110000110000000000101
#        Step 1 Str:  100100010110000110000000000101
#        Step 2 Str:  000100010110000110000000000100
#        Step 3 Str:  000110010010001110000000100000
#        Step 4 Str:  100110010010001110000000100001
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.38%)
#     Cycle Start Str:  110110000101001010100001111000
#        Step 1 Str:  110110000101001010100001111000
#        Step 2 Str:  100110000111001110010001111000
#        Step 3 Str:  100010000011001110000001111000
#        Step 4 Str:  100110000011001110000001111001
#        Step 5 Str:  101100000110000110000000011101
#        Step 6 Str:  001100000110000010100000101100
#        Step 7 Str:  111110000101001010100001101000
# --- End of Attractor Listing ---
# Attractor simulation time : 15.952812433242798
#                   Ratio
# phenotype
# P_epithelial   0.014042
# P_hybrid_high  0.493768
# P_mesenchymal  0.492190
# --- Attractor 비교 결과 (original에서 노드 28 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 28 제거 후): ('111001101111111111111111111010',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111111010',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 28 제거 후): ('100100010110000110000000000101', '000100010110000110000000000100', '000110010010001110000000100000', '100110010010001110000000100001')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('100100010110000110000000000101', '000100010110000110000000000100', '000110010010001110000000100000', '100110010010001110000000100001')
# ------------------------------
# ❌ Original 2번 어트랙터 (노드 28 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100')
#    (노드 제거 후): ('110110000101001010100001111000', '100110000111001110000001111000', '100110000011001110000001111000', '100110000011001110000001111001', '101100000111000110000000011101', '001100000110000010100000101100', '111110000101001010100001101000')
# ------------------------------
# ------remove logic of p38------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.39%)
#     State Str:  111001101111111111111111111000
#   > Attractor ID 1 (Cyclic, Length 4, Basin 1.34%)
#     Cycle Start Str:  000110010010001110000000100010
#        Step 1 Str:  000110010010001110000000100010
#        Step 2 Str:  100110010010001110000000100011
#        Step 3 Str:  100100010110000110000000000111
#        Step 4 Str:  000100010110000110000000000110
#   > Attractor ID 2 (Cyclic, Length 7, Basin 49.26%)
#     Cycle Start Str:  110110000101001010100001111010
#        Step 1 Str:  110110000101001010100001111010
#        Step 2 Str:  100110000111001110000001111000
#        Step 3 Str:  100110000011001110000001111000
#        Step 4 Str:  100110000011001110000001111001
#        Step 5 Str:  101100000111000110000000011111
#        Step 6 Str:  001100000110000010100000101110
#        Step 7 Str:  111110000101001010100001101010
# --- End of Attractor Listing ---
# Attractor simulation time : 15.804039239883423
#                   Ratio
# phenotype
# P_epithelial   0.013430
# P_hybrid_high  0.492624
# P_mesenchymal  0.493945
# --- Attractor 비교 결과 (original에서 노드 29 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 29 제거 후): ('111001101111111111111111111000',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111111000',)
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 1번 (원본: ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101'), Cyclic)
#     (노드 29 제거 후): ('100100010110000110000000000111', '000100010110000110000000000110', '000110010010001110000000100010', '100110010010001110000000100011')
#   - New     : 1번 (Cyclic)
#     어트랙터: ('000110010010001110000000100010', '100110010010001110000000100011', '100100010110000110000000000111', '000100010110000110000000000110')
# ------------------------------
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 2번 (원본: ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100'), Cyclic)
#     (노드 29 제거 후): ('110110000101001010100001111010', '100110000111001110000001111000', '100110000011001110000001111000', '100110000011001110000001111001', '101100000111000110000000011111', '001100000110000010100000101110', '111110000101001010100001101010')
#   - New     : 2번 (Cyclic)
#     어트랙터: ('110110000101001010100001111010', '100110000111001110000001111000', '100110000011001110000001111000', '100110000011001110000001111001', '101100000111000110000000011111', '001100000110000010100000101110', '111110000101001010100001101010')
# ------------------------------
# ------remove logic of p53------
# {'RAS': 1}
# WARNING The state transition graph will consist of up to 2**30=1073741824 states, depending on the initial states.
#
# --- [Simulation Function] Detected Attractors for Current Perturbation ---
#   > Attractor ID 0 (Steady State, Basin 49.67%)
#     State Str:  111001101111111111111111111001
#   > Attractor ID 1 (Cyclic, Length 2, Basin 1.34%)
#     Cycle Start Str:  000110010010001110000001100010
#        Step 1 Str:  000110010010001110000001100010
#        Step 2 Str:  100100010110000110000000000110
#   > Attractor ID 2 (Cyclic, Length 2, Basin 3.01%)
#     Cycle Start Str:  000010000011001010100001101000
#        Step 1 Str:  000010000011001010100001101000
#        Step 2 Str:  101100000110000110010000011110
#   > Attractor ID 3 (Cyclic, Length 2, Basin 2.74%)
#     Cycle Start Str:  000110000011001110000001100010
#        Step 1 Str:  000110000011001110000001100010
#        Step 2 Str:  100100010110000110000000001110
#   > Attractor ID 4 (Cyclic, Length 2, Basin 5.46%)
#     Cycle Start Str:  000110000011001010100001100010
#        Step 1 Str:  000110000011001010100001100010
#        Step 2 Str:  101100010110000110000000001110
#   > Attractor ID 5 (Cyclic, Length 2, Basin 37.78%)
#     Cycle Start Str:  101100000110000110000000011110
#        Step 1 Str:  101100000110000110000000011110
#        Step 2 Str:  000110000011001010100001101010
# --- End of Attractor Listing ---
# Attractor simulation time : 17.628621816635132
#                   Ratio
# phenotype
# P_epithelial   0.095402
# P_hybrid_high  0.407886
# P_mesenchymal  0.496712
# --- Attractor 비교 결과 (original에서 노드 30 제거 후) ---
# ✅ 동일한 attractor를 찾았습니다!
#   - Original: 0번 (원본: ('1110011011111111111111111110010',), Steady-state)
#     (노드 30 제거 후): ('111001101111111111111111111001',)
#   - New     : 0번 (Steady-state)
#     어트랙터: ('111001101111111111111111111001',)
# ------------------------------
# ❌ Original 1번 어트랙터 (노드 30 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1001000101100001100000000001101', '0001000101100001100000000001100', '0001100100100011100000001000100', '1001100100100011100000001000101')
#    (노드 제거 후): ('100100010110000110000000000110', '000100010110000110000000000110', '000110010010001110000000100010', '100110010010001110000000100010')
# ------------------------------
# ❌ Original 2번 어트랙터 (노드 30 제거 후)는 New 어트랙터에서 일치하는 것을 찾지 못했습니다.
#    (노드 제거 전): ('1101100001010010101000011110100', '1001100001110011100000011110000', '1001100000110011100000011110000', '1001100000110011100000011110001', '1011000001110001100000000111101', '0011000001100000101000001011100', '1111100001010010101000011010100')
#    (노드 제거 후): ('110110000101001010100001111010', '100110000111001110000001111000', '100110000011001110000001111000', '100110000011001110000001111000', '101100000111000110000000011110', '001100000110000010100000101110', '111110000101001010100001101010')
# ------------------------------
